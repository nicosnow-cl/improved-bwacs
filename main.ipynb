# %%
from IPython.core.display import display, HTML
# %config IPCompleter.greedy = True
display(HTML("<style>.container { width: 100% !important; }</style>"))
# Out:
# <style>.container { width: 100% !important; }</style>

# %%
# Import libraries and define constants

import os
from datetime import datetime
from free_bwacs_model import FreeBWACS
from restricted_bwacs_model import RestrictedBWACS
from src.helpers import sorted_alphanumeric, save_results_on_file

RUNS = 10
INSTANCES_FOLDER = 'instances/CVRPLIB/CMT'
INSTANCES = sorted_alphanumeric([instance_name.replace(
    '.vrp', '') for instance_name in os.listdir(INSTANCES_FOLDER)])
# INSTANCES = ['CMT1']
SAVE_RESULTS = True
SAVE_IMGS = False
RESULTS_FILE_WITH_HEADER = True
BASE_RESULTS_FOLDER = 'results'
THIS_EXECUTION_FOLDER = datetime.now().strftime("%Y%m%d_%H%M%S")

# %%
# Execution of runs for instances files for FREE-ANT

instances_with_errors = []
cluster_type = 'kmeans'  # 'kmeans' or 'kmedoids'
ant_type = 'fa'  # 'fa', 'ra' or 'random'

# Validation of folder to save results
if SAVE_RESULTS:
    if not os.path.exists(BASE_RESULTS_FOLDER):
        os.makedirs(BASE_RESULTS_FOLDER)

# Start running the algorithm
for instance in INSTANCES:
    
    solution_list = []
    results_folder = f'{THIS_EXECUTION_FOLDER}/{instance}'
    file_name = f'{str(instance).lower()}_{ant_type}_{cluster_type}'

    if SAVE_IMGS: os.makedirs(f'{BASE_RESULTS_FOLDER}/{results_folder}/imgs', exist_ok=True)
    
    for run in range(RUNS):
        try:
            bwacs = FreeBWACS(
                instance=f'{INSTANCES_FOLDER}/{instance}',
                max_nodes=9999,
                cluster_type=cluster_type,
                metric='euclidian',
                tare_percentage=0.15,
                max_iterations=100,
                total_ant_divider=1,
                only_k_optimum=True,
                start_ant_on_best_nodes=True,
                # heuristic_type will let you choice what information gotta build the heuristic information matrix
                # 0 - Only distances data / Best beta: 5
                # 1 - Only energies data / Best gamma: 5
                # 2 - Distances data * energies data / Best parameters: 5 - 5
                # 3 - Only distances data of Savings algorithm / Best delta: 1
                # 4 - Only energies data of Savings algorithm / Best eta: 2
                # 5 - Distances data * distances savings data / Best parameters: 4 - 5
                # 6 - Energies data * energies savings data / Best parameters: 5 - 5
                # 7 - Distances data * energies data * distances savings data / Best parameters: 3 - 4 - 3
                # 8 - Distances data * energies data * energies savings data / Best parameters: 3 - 4 - 3
                # 9 - Distances data * energies data * distances savings data * capacity utilization data / Best parameters: 2 - 4 - 4 - 2
                # 10 - Distances data * energies data * distances savings data * capacity utilization data / Best parameters: 2 - 4 - 4 - 2
                # 11 - Distances data * energies data * distances savings data * energies savings data * capacity utilization data / Best parameters: 2 - 4 - 3 - 4 - 1
                heuristic_type=2,
                # Importance of pheromones trace. Recommended alpha value in: [1, 4]
                alpha=3,
                # Importance of distance heuristic information. Recommended beta value in: [2, 5]
                beta=2,
                # Importance of energy heuristic information. Recommended gamma value in: [2, 5]
                gamma=3,
                # Importance of distances's Savings Algorithm information. Recommended delta value in: [0, 2]
                delta=1,
                # Importance of energies's Savings Algorithm information. Recommended eta value in: [0, 2]
                eta=1,
                # Importance of vehicle's capacity utilization. Recommended mi value in: [0, 2]
                mi=0,
                # Define the strategy used for pheromone updating. - options: | 0 - 1 |
                # The value 0 is for the classic function in ACO: 1 / Best_Solution_Quality
                # The value 1 if for the improve function know as Ant Weight Strategy.
                pheromone_updating_strategy=0,
                local_ant_update_pheromones=False,
                best_iteration_ant_update_pheromones=False,
                best_global_ant_update_pheromones=True,
                penalize_worst_solution=True,
                mutate_pheromones_matrix=True,
                # Evaporation rate of the pheromones by the next function: phoromone =  (1 - p) * pheromone. Recommended value for p: 0.02.
                p=0.02,
                # Mutation probability for every row of the pheromones matrix, such as: mutate if (random number between 0 and 1) <= Pm
                # Recommended value for Pm: 0.3.
                Pm=0.3,
                # Mutation intensity for the pheromones matrix. Recommended value for sigma in: [2, 4]
                sigma=3,
                # Constant used in Pseudorandom Transition Rule. This is a probability of choice the next node by argmax, define in Ant Colony System.
                # Recommended value for l0 in: [0.2, 0.4]
                l0=0.3,
                # Constant used for a lot of functions, such as: f(.) = H / specific_values.
                H=1,
                ls_ant_solution=False,
                ls_best_iteration=True,
                ls_best_global=False,
                use_normalized_matrix=False,
                print_instance=False,
                print_clusters=False,
                print_solution=False,
                print_distance_matrix=False,
                print_energy_matrix=False,
                print_distance_saving_matrix=False,
                print_energy_saving_matrix=False,
                print_combination_matrix=False,
                print_pheromone_matrix=False,
                output_sol_img=f'{BASE_RESULTS_FOLDER}/{results_folder}/imgs/{file_name}.png'
            )

            solution_energy, solution_arcs, solution_distance, solution_time = bwacs.solve()
            solution_list.append(
                (solution_energy, solution_arcs, solution_distance, solution_time))
        except Exception as e:
            instances_with_errors.append((instance, e))
            break
    
    if (len(solution_list) > 0): 
        print(f'Solutions for instance {instance}: {solution_list}')
        print(f'{RUNS} runs for instance {instance} finished at {datetime.now().strftime("%Y%m%d_%H%M%S")}')
        print(
            f'Best solution for instance {instance}: {min(solution_list, key=lambda x: x[0])}')
        print(
            f'Worst solution for instance {instance}: {max(solution_list or [], key=lambda x: x[0])}')
        

        if SAVE_RESULTS:
            os.makedirs(
                f'{BASE_RESULTS_FOLDER}/{results_folder}', exist_ok=True)
            save_results_on_file(f'{BASE_RESULTS_FOLDER}/{results_folder}', file_name, ant_type, cluster_type,
                                solution_list, instance, 'csv', 'energy,arcs,distance,time(ms)')

if  len(instances_with_errors) > 0: 
    print(f'Instances with errors: {instances_with_errors}')
    os.makedirs(f'{BASE_RESULTS_FOLDER}/{results_folder}', exist_ok=True)
    error_file = open(f'{BASE_RESULTS_FOLDER}/{THIS_EXECUTION_FOLDER}/error_instances.txt', 'a')
    for instance, error in instances_with_errors:
        error_file.write(f'{instance}: {error}\n')
    error_file.close()
# Out:
# • INITIALIZING ALGORITHM •
# ------------------------------
#
# • 0. Reading instance file
# ------------------------------
#
#     - Parameters:
#         > Instance name: instances/CVRPLIB/CMT/CMT1
#         > Number of nodes: 51
#         > Nodes and demands: {0: 0, 1: 7, 2: 30, 3: 16, 4: 9, 5: 21, 6: 15, 7: 19, 8: 23, 9: 11, 10: 5, 11: 19, 12: 29, 13: 23, 14: 21, 15: 10, 16: 15, 17: 3, 18: 41, 19: 9, 20: 28, 21: 8, 22: 8, 23: 16, 24: 10, 25: 28, 26: 7, 27: 15, 28: 14, 29: 6, 30: 19, 31: 11, 32: 12, 33: 23, 34: 26, 35: 17, 36: 6, 37: 9, 38: 15, 39: 14, 40: 7, 41: 27, 42: 13, 43: 11, 44: 16, 45: 10, 46: 5, 47: 25, 48: 17, 49: 18, 50: 10}
#         > Total demand: 777 units
#         > Vehicles capacity: 160 units
#         > K-Optimum: 5
#         > Tightness ratio: 0.97125
#         > Total of iterations: 100
#         > Number of ants per iteration: 50
#
# • 1. Starting clustering process
# ------------------------------
#
#     > CLUSTER TYPE: KMEANS
#     > ITERACIÓN 1
#         - Centroides actuales: [array([57, 58]), array([17, 33]), array([10, 17]), array([61, 33]), array([ 7, 38])]
#         - Nodos sin asignar: [ 7 30], [23 11]
#         - Mejor costo anterior: inf
#         - Costo total actual: 9739.5597891085
#
#     > ITERACIÓN 2
#         - Centroides actuales: [array([37., 69.]), array([29.11111111, 31.44444444]), array([22.77777778, 13.55555556]), array([54.4, 31.2]), array([16.8, 53.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 9739.5597891085
#         - Costo total actual: 9469.008712103712
#
#     > ITERACIÓN 3
#         - Centroides actuales: [array([41.3, 59.2]), array([32.44444444, 33.77777778]), array([21.22222222, 14.88888889]), array([46., 10.]), array([20.4, 53.5])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 10376.00191633337
#
#     > ITERACIÓN 4
#         - Centroides actuales: [array([63., 69.]), array([39.3, 34.7]), array([21., 21.]), array([50.        , 22.33333333]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 9382.963165716292
#
#     > ITERACIÓN 5
#         - Centroides actuales: [array([52.5, 58.6]), array([39.8, 38.5]), array([18., 19.]), array([50.        , 21.44444444]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 9382.963165716292
#         - Costo total actual: 9131.213913563224
#
#     > ITERACIÓN 6
#         - Centroides actuales: [array([27., 68.]), array([40.3, 40.1]), array([20.8, 21.9]), array([48.1, 25.5]), array([ 5., 64.])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 12447.104568066417
#
#     > ITERACIÓN 7
#         - Centroides actuales: [array([40.54545455, 57.        ]), array([44.6, 42.5]), array([20. , 19.7]), array([50.7, 25. ]), array([17.        , 50.11111111])]
#         - Nodos sin asignar: [12], [23]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9205.552639738571
#
#     > ITERACIÓN 8
#         - Centroides actuales: [array([43.8, 61.5]), array([47.        , 39.45454545]), array([ 5., 25.]), array([50.11111111, 23.66666667]), array([15.66666667, 51.77777778])]
#         - Nodos sin asignar: [11], [29]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9274.450376400218
#
#     > ITERACIÓN 9
#         - Centroides actuales: [array([43.72727273, 58.54545455]), array([31., 32.]), array([12.25, 21.  ]), array([45.18181818, 21.36363636]), array([17.66666667, 51.11111111])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 10115.12837053417
#
#     > ITERACIÓN 10
#         - Centroides actuales: [array([44.4, 57.2]), array([40.09090909, 35.54545455]), array([12.25, 21.  ]), array([49. , 22.3]), array([25.36363636, 54.18181818])]
#         - Nodos sin asignar: [43], [16]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 8770.75270035537
#
#     > ITERACIÓN 11
#         - Centroides actuales: [array([51.09090909, 58.        ]), array([39.3, 35.5]), array([30., 15.]), array([50.        , 21.44444444]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9769.457396640944
#
#     > ITERACIÓN 12
#         - Centroides actuales: [array([51.44444444, 58.55555556]), array([40.4, 40.7]), array([24.5, 18.5]), array([44.1, 23.5]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9149.19296884423
#
#     > ITERACIÓN 13
#         - Centroides actuales: [array([27., 68.]), array([38.8, 42.6]), array([21.4, 22.6]), array([49. , 22.3]), array([ 5., 64.])]
#         - Nodos sin asignar: [20], [8]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 11671.139732542391
#
#     > ITERACIÓN 14
#         - Centroides actuales: [array([43.9, 63.2]), array([62., 42.]), array([20. , 19.7]), array([49. , 22.3]), array([16.55555556, 48.44444444])]
#         - Nodos sin asignar: [39], [7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10696.56634254118
#
#     > ITERACIÓN 15
#         - Centroides actuales: [array([41.16666667, 61.58333333]), array([47.77777778, 39.        ]), array([5., 6.]), array([46. , 22.2]), array([18.66666667, 49.        ])]
#         - Nodos sin asignar: [46], [25]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10035.503670792263
#
#     > ITERACIÓN 16
#         - Centroides actuales: [array([45.1, 62.9]), array([51.5, 40.5]), array([16.44444444, 18.66666667]), array([44. , 21.1]), array([25., 32.])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10623.636803568075
#
#     > ITERACIÓN 17
#         - Centroides actuales: [array([41.41666667, 60.58333333]), array([53.6, 37.4]), array([15.22222222, 25.44444444]), array([40.        , 28.88888889]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9746.613717133847
#
#     > ITERACIÓN 18
#         - Centroides actuales: [array([44.9, 59.3]), array([54.63636364, 37.09090909]), array([15.88888889, 20.55555556]), array([46., 10.]), array([15.33333333, 54.        ])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9550.93543363689
#
#     > ITERACIÓN 19
#         - Centroides actuales: [array([63., 69.]), array([54.8, 40. ]), array([18.88888889, 22.33333333]), array([38.5, 18.3]), array([17.3, 50.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10439.904257073627
#
#     > ITERACIÓN 20
#         - Centroides actuales: [array([47.3, 61. ]), array([48.09090909, 35.36363636]), array([18.88888889, 24.22222222]), array([41.2, 19.9]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24 25], [28  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 8306.319175559167
#
#     > ITERACIÓN 21
#         - Centroides actuales: [array([50. , 59.6]), array([51.4, 36.3]), array([ 7., 38.]), array([36.9, 17.7]), array([27., 68.])]
#         - Nodos sin asignar: [38 18], [14  9]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 10173.537298092959
#
#     > ITERACIÓN 22
#         - Centroides actuales: [array([50.11111111, 56.33333333]), array([47.18181818, 33.54545455]), array([15.25, 37.75]), array([13., 13.]), array([23.5, 55.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9888.028925395214
#
#     > ITERACIÓN 23
#         - Centroides actuales: [array([51.18181818, 55.90909091]), array([50.5, 32.6]), array([17.55555556, 38.66666667]), array([22.4, 16.7]), array([30.2, 49.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8779.285862604613
#
#     > ITERACIÓN 24
#         - Centroides actuales: [array([52.81818182, 52.63636364]), array([46., 10.]), array([18.83333333, 37.33333333]), array([21.63636364, 16.63636364]), array([24.18181818, 55.09090909])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11160.760494587392
#
#     > ITERACIÓN 25
#         - Centroides actuales: [array([53.2, 50. ]), array([48.63636364, 29.63636364]), array([20.57142857, 34.57142857]), array([23.09090909, 23.90909091]), array([26.09090909, 56.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9326.960082949558
#
#     > ITERACIÓN 26
#         - Centroides actuales: [array([53.9, 53.2]), array([47.5, 32.3]), array([18.85714286, 38.28571429]), array([23.66666667, 16.08333333]), array([29.27272727, 57.63636364])]
#         - Nodos sin asignar: [12 32], [23 23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8422.104191179695
#
#     > ITERACIÓN 27
#         - Centroides actuales: [array([49.54545455, 51.27272727]), array([46., 10.]), array([ 5., 25.]), array([25.33333333, 16.88888889]), array([25.6, 57. ])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11012.655751743518
#
#     > ITERACIÓN 28
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([49. , 22.3]), array([ 9.85714286, 24.85714286]), array([35.27272727, 33.27272727]), array([23.63636364, 59.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9547.94009204571
#
#     > ITERACIÓN 29
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([52.27272727, 29.54545455]), array([12.        , 27.71428571]), array([28.90909091, 26.54545455]), array([23. , 60.4])]
#         - Nodos sin asignar: [27 35], [14  6]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8066.528567941032
#
#     > ITERACIÓN 30
#         - Centroides actuales: [array([63., 69.]), array([52.45454545, 26.45454545]), array([12.        , 27.71428571]), array([27.9, 22.5]), array([21.7, 58.5])]
#         - Nodos sin asignar: [32 10], [23 19]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9162.6705524307
#
#     > ITERACIÓN 31
#         - Centroides actuales: [array([48.18181818, 53.81818182]), array([42., 41.]), array([12.        , 27.71428571]), array([31.3, 22.9]), array([23.18181818, 55.81818182])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9781.030433449172
#
#     > ITERACIÓN 32
#         - Centroides actuales: [array([47.90909091, 55.09090909]), array([49.63636364, 36.54545455]), array([12.71428571, 25.28571429]), array([31.5, 18.1]), array([25.        , 53.09090909])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8647.195431821801
#
#     > ITERACIÓN 33
#         - Centroides actuales: [array([63., 69.]), array([50.5, 32.6]), array([12.        , 27.71428571]), array([31.90909091, 17.36363636]), array([22.72727273, 54.63636364])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10224.697698766111
#
#     > ITERACIÓN 34
#         - Centroides actuales: [array([53.09090909, 54.63636364]), array([48.63636364, 34.63636364]), array([12.71428571, 25.28571429]), array([29.09090909, 22.27272727]), array([22.4, 54.6])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8205.405893565472
#
#     > ITERACIÓN 35
#         - Centroides actuales: [array([51.18181818, 57.45454545]), array([59., 15.]), array([12.        , 27.71428571]), array([29.2, 17.6]), array([22.63636364, 55.18181818])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9840.425181254781
#
#     > ITERACIÓN 36
#         - Centroides actuales: [array([51.6, 56.2]), array([53. , 31.5]), array([12.71428571, 25.28571429]), array([32.33333333, 23.83333333]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9209.872196275994
#
#     > ITERACIÓN 37
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([53.27272727, 32.09090909]), array([12.        , 27.71428571]), array([46., 10.]), array([18.5, 52.2])]
#         - Nodos sin asignar: [18 39], [9 7]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8682.729335656946
#
#     > ITERACIÓN 38
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([5., 6.]), array([38.5, 18.1]), array([19.2, 55.8])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9938.838033288544
#
#     > ITERACIÓN 39
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([12.25, 21.  ]), array([59., 15.]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24 42], [28 11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8844.914022470824
#
#     > ITERACIÓN 40
#         - Centroides actuales: [array([48.36363636, 57.72727273]), array([46.6, 36.5]), array([ 7., 38.]), array([45.77777778, 18.77777778]), array([ 5., 64.])]
#         - Nodos sin asignar: [40], [27]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10771.024281503887
#
#     > ITERACIÓN 41
#         - Centroides actuales: [array([48.18181818, 52.27272727]), array([46.33333333, 36.44444444]), array([10., 17.]), array([42. , 17.4]), array([20.4, 53.5])]
#         - Nodos sin asignar: [30], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9760.871029384165
#
#     > ITERACIÓN 42
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:438: RuntimeWarning: divide by zero encountered in true_divide
#   1, self.distances_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:462: RuntimeWarning: divide by zero encountered in true_divide
#   1, self.energies_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:568: RuntimeWarning: divide by zero encountered in true_divide
#   self.np.divide(1, self.distances_matrix), self.beta)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:570: RuntimeWarning: divide by zero encountered in true_divide
#   self.np.divide(1, self.energies_matrix), self.gamma)
#         - Centroides actuales: [array([37., 69.]), array([48.6, 34.4]), array([19.88888889, 25.66666667]), array([35.8, 20.2]), array([19.2, 55.8])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9867.190655216931
#
#     > Mejor Clusterización: [array([ 2, 16, 29, 11, 22, 32, 20,  1,  3, 35], dtype=int64), array([ 9, 49, 30, 50, 10, 38, 34, 21, 39, 33, 45], dtype=int64), array([18, 13,  4, 41, 25, 14, 19], dtype=int64), array([17, 37, 12, 47, 44,  5, 15, 46, 42, 40], dtype=int64), array([48,  7, 23,  8, 26,  6, 27, 31, 24, 43], dtype=int64)], con costo final: 8066.528567941032, nodos sin asignar: [28 36]
#     > Mejor Clusterización (Contraint): [array([ 2, 29, 20, 16, 21, 22,  3, 11, 35, 36], dtype=int64), array([49,  9, 38,  5, 10, 30, 50, 34, 39, 43], dtype=int64), array([18, 47, 12, 14, 46, 25, 24], dtype=int64), array([ 4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], dtype=int64), array([48,  8, 27, 23,  6,  7,  1, 26, 32, 31, 28], dtype=int64)], con costo final: 9326.960082949558, nodos sin asignar: []
#     --- 0.21699976921081543 seconds ---
#
#     - Generated Clusters
#          > Cluster 0: [2, 29, 20, 16, 21, 22, 3, 11, 35, 36], with total demand: 153
#          > Cluster 1: [49, 9, 38, 5, 10, 30, 50, 34, 39, 43], with total demand: 150
#          > Cluster 2: [18, 47, 12, 14, 46, 25, 24], with total demand: 159
#          > Cluster 3: [4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], with total demand: 159
#          > Cluster 4: [48, 8, 27, 23, 6, 7, 1, 26, 32, 31, 28], with total demand: 156
#          > Total nodes (without depot): 50
#
# • 2. Starting BWAS algorithm (Free Ant)
# ------------------------------
#
# [(2, 29), (2, 20), (2, 16), (2, 21), (2, 22), (2, 3), (2, 11), (2, 35), (2, 36), (29, 2), (29, 20), (29, 16), (29, 21), (29, 22), (29, 3), (29, 11), (29, 35), (29, 36), (20, 2), (20, 29), (20, 16), (20, 21), (20, 22), (20, 3), (20, 11), (20, 35), (20, 36), (16, 2), (16, 29), (16, 20), (16, 21), (16, 22), (16, 3), (16, 11), (16, 35), (16, 36), (21, 2), (21, 29), (21, 20), (21, 16), (21, 22), (21, 3), (21, 11), (21, 35), (21, 36), (22, 2), (22, 29), (22, 20), (22, 16), (22, 21), (22, 3), (22, 11), (22, 35), (22, 36), (3, 2), (3, 29), (3, 20), (3, 16), (3, 21), (3, 22), (3, 11), (3, 35), (3, 36), (11, 2), (11, 29), (11, 20), (11, 16), (11, 21), (11, 22), (11, 3), (11, 35), (11, 36), (35, 2), (35, 29), (35, 20), (35, 16), (35, 21), (35, 22), (35, 3), (35, 11), (35, 36), (36, 2), (36, 29), (36, 20), (36, 16), (36, 21), (36, 22), (36, 3), (36, 11), (36, 35)]
# [(49, 9), (49, 38), (49, 5), (49, 10), (49, 30), (49, 50), (49, 34), (49, 39), (49, 43), (9, 49), (9, 38), (9, 5), (9, 10), (9, 30), (9, 50), (9, 34), (9, 39), (9, 43), (38, 49), (38, 9), (38, 5), (38, 10), (38, 30), (38, 50), (38, 34), (38, 39), (38, 43), (5, 49), (5, 9), (5, 38), (5, 10), (5, 30), (5, 50), (5, 34), (5, 39), (5, 43), (10, 49), (10, 9), (10, 38), (10, 5), (10, 30), (10, 50), (10, 34), (10, 39), (10, 43), (30, 49), (30, 9), (30, 38), (30, 5), (30, 10), (30, 50), (30, 34), (30, 39), (30, 43), (50, 49), (50, 9), (50, 38), (50, 5), (50, 10), (50, 30), (50, 34), (50, 39), (50, 43), (34, 49), (34, 9), (34, 38), (34, 5), (34, 10), (34, 30), (34, 50), (34, 39), (34, 43), (39, 49), (39, 9), (39, 38), (39, 5), (39, 10), (39, 30), (39, 50), (39, 34), (39, 43), (43, 49), (43, 9), (43, 38), (43, 5), (43, 10), (43, 30), (43, 50), (43, 34), (43, 39)]
# [(18, 47), (18, 12), (18, 14), (18, 46), (18, 25), (18, 24), (47, 18), (47, 12), (47, 14), (47, 46), (47, 25), (47, 24), (12, 18), (12, 47), (12, 14), (12, 46), (12, 25), (12, 24), (14, 18), (14, 47), (14, 12), (14, 46), (14, 25), (14, 24), (46, 18), (46, 47), (46, 12), (46, 14), (46, 25), (46, 24), (25, 18), (25, 47), (25, 12), (25, 14), (25, 46), (25, 24), (24, 18), (24, 47), (24, 12), (24, 14), (24, 46), (24, 25)]
# [(4, 17), (4, 37), (4, 44), (4, 42), (4, 41), (4, 19), (4, 15), (4, 13), (4, 45), (4, 40), (4, 33), (17, 4), (17, 37), (17, 44), (17, 42), (17, 41), (17, 19), (17, 15), (17, 13), (17, 45), (17, 40), (17, 33), (37, 4), (37, 17), (37, 44), (37, 42), (37, 41), (37, 19), (37, 15), (37, 13), (37, 45), (37, 40), (37, 33), (44, 4), (44, 17), (44, 37), (44, 42), (44, 41), (44, 19), (44, 15), (44, 13), (44, 45), (44, 40), (44, 33), (42, 4), (42, 17), (42, 37), (42, 44), (42, 41), (42, 19), (42, 15), (42, 13), (42, 45), (42, 40), (42, 33), (41, 4), (41, 17), (41, 37), (41, 44), (41, 42), (41, 19), (41, 15), (41, 13), (41, 45), (41, 40), (41, 33), (19, 4), (19, 17), (19, 37), (19, 44), (19, 42), (19, 41), (19, 15), (19, 13), (19, 45), (19, 40), (19, 33), (15, 4), (15, 17), (15, 37), (15, 44), (15, 42), (15, 41), (15, 19), (15, 13), (15, 45), (15, 40), (15, 33), (13, 4), (13, 17), (13, 37), (13, 44), (13, 42), (13, 41), (13, 19), (13, 15), (13, 45), (13, 40), (13, 33), (45, 4), (45, 17), (45, 37), (45, 44), (45, 42), (45, 41), (45, 19), (45, 15), (45, 13), (45, 40), (45, 33), (40, 4), (40, 17), (40, 37), (40, 44), (40, 42), (40, 41), (40, 19), (40, 15), (40, 13), (40, 45), (40, 33), (33, 4), (33, 17), (33, 37), (33, 44), (33, 42), (33, 41), (33, 19), (33, 15), (33, 13), (33, 45), (33, 40)]
# [(48, 8), (48, 27), (48, 23), (48, 6), (48, 7), (48, 1), (48, 26), (48, 32), (48, 31), (48, 28), (8, 48), (8, 27), (8, 23), (8, 6), (8, 7), (8, 1), (8, 26), (8, 32), (8, 31), (8, 28), (27, 48), (27, 8), (27, 23), (27, 6), (27, 7), (27, 1), (27, 26), (27, 32), (27, 31), (27, 28), (23, 48), (23, 8), (23, 27), (23, 6), (23, 7), (23, 1), (23, 26), (23, 32), (23, 31), (23, 28), (6, 48), (6, 8), (6, 27), (6, 23), (6, 7), (6, 1), (6, 26), (6, 32), (6, 31), (6, 28), (7, 48), (7, 8), (7, 27), (7, 23), (7, 6), (7, 1), (7, 26), (7, 32), (7, 31), (7, 28), (1, 48), (1, 8), (1, 27), (1, 23), (1, 6), (1, 7), (1, 26), (1, 32), (1, 31), (1, 28), (26, 48), (26, 8), (26, 27), (26, 23), (26, 6), (26, 7), (26, 1), (26, 32), (26, 31), (26, 28), (32, 48), (32, 8), (32, 27), (32, 23), (32, 6), (32, 7), (32, 1), (32, 26), (32, 31), (32, 28), (31, 48), (31, 8), (31, 27), (31, 23), (31, 6), (31, 7), (31, 1), (31, 26), (31, 32), (31, 28), (28, 48), (28, 8), (28, 27), (28, 23), (28, 6), (28, 7), (28, 1), (28, 26), (28, 32), (28, 31)]
#     • Preliminar parameters:
#         > Tmin value: 2.1068781023028867e-14
#         > Tmax value: 2.1068781023028865e-11
#         > Initial candidate list: [10, 4, 45, 3, 26, 35, 19, 12, 23, 46, 40, 41, 29, 22, 28, 14, 36, 9, 42, 11, 24, 18, 17, 20, 38, 5, 31, 39, 49, 7, 34, 30, 32, 21, 25, 1, 6, 8, 43, 13, 33, 48, 44, 37, 50, 27, 2, 15, 16, 47]
#
#
#     • Iteration 1
#         > Mean quality of the solutions in this iteration : 87998.66652660287
#         + New best energy: 72470, with the next distance: 695
#
#     • Iteration 2
#         > Mean quality of the solutions in this iteration : 88895.77891594304
#
#     • Iteration 3
#         > Mean quality of the solutions in this iteration : 86503.80337867246
#         + New best energy: 72423, with the next distance: 737
#
#     • Iteration 4
#         > Mean quality of the solutions in this iteration : 89037.61722067659
#         + New best energy: 69605, with the next distance: 695
#
#     • Iteration 5
#         > Mean quality of the solutions in this iteration : 86458.21331194391
#         + New best energy: 63575, with the next distance: 643
#
#     • Iteration 6
#         > Mean quality of the solutions in this iteration : 90002.62009613987
#
#     • Iteration 7
#         > Mean quality of the solutions in this iteration : 87569.7583994006
#
#     • Iteration 8
#         > Mean quality of the solutions in this iteration : 88073.06620678506
#
#     • Iteration 9
#         > Mean quality of the solutions in this iteration : 88458.47913700253
#
#     • Iteration 10
#         > Mean quality of the solutions in this iteration : 87435.13733555528
#
#     • Iteration 11
#         > Mean quality of the solutions in this iteration : 88829.04670263102
#
#     • Iteration 12
#         > Mean quality of the solutions in this iteration : 86601.22282916629
#
#     • Iteration 13
#         > Mean quality of the solutions in this iteration : 88613.50449967744
#
#     • Iteration 14
#         > Mean quality of the solutions in this iteration : 87127.56389068614
#
#     • Iteration 15
#         > Mean quality of the solutions in this iteration : 87277.46915425331
#
#     • Iteration 16
#         > Mean quality of the solutions in this iteration : 87783.0797553708
#
#     • Iteration 17
#         > Mean quality of the solutions in this iteration : 85679.64962848324
#
#     • Iteration 18
#         > Mean quality of the solutions in this iteration : 88786.31466927571
#         + New best energy: 63484, with the next distance: 669
#
#     • Iteration 19
#         > Mean quality of the solutions in this iteration : 87860.09542302195
#
#     • Iteration 20
#         > Mean quality of the solutions in this iteration : 87231.86720972216
#
#     • Iteration 21
#         > Mean quality of the solutions in this iteration : 84368.70970521163
#
#     • Iteration 22
#         > Mean quality of the solutions in this iteration : 86939.21945813645
#
#     • Iteration 23
#         > Mean quality of the solutions in this iteration : 88007.13938560936
#
#     • Iteration 24
#         > Mean quality of the solutions in this iteration : 87412.29913222721
#
#     • Iteration 25
#         > Mean quality of the solutions in this iteration : 88171.91216712858
#
#     • Iteration 26
#         > Mean quality of the solutions in this iteration : 85729.1569208304
#
#     • Iteration 27
#         > Mean quality of the solutions in this iteration : 88848.07694212622
#
#     • Iteration 28
#         > Mean quality of the solutions in this iteration : 86304.0604978194
#
#     • Iteration 29
#         > Mean quality of the solutions in this iteration : 87700.33184289893
#
#     • Iteration 30
#         > Mean quality of the solutions in this iteration : 88322.05700149613
#
#     • Iteration 31
#         > Mean quality of the solutions in this iteration : 90615.89293612033
#
#     • Iteration 32
#         > Mean quality of the solutions in this iteration : 86804.9229405107
#
#     • Iteration 33
#         > Mean quality of the solutions in this iteration : 87923.84339056801
#
#     • Iteration 34
#         > Mean quality of the solutions in this iteration : 87737.46407335094
#         + New best energy: 52007, with the next distance: 609
#
#     • Iteration 35
#         > Mean quality of the solutions in this iteration : 87397.77250155581
#
#     • Iteration 36
#         > Mean quality of the solutions in this iteration : 87777.89626366804
#
#     • Iteration 37
#         > Mean quality of the solutions in this iteration : 86632.02513468207
#
#     • Iteration 38
#         > Mean quality of the solutions in this iteration : 86888.18706871424
#
#     • Iteration 39
#         > Mean quality of the solutions in this iteration : 85665.39293144856
#
#     • Iteration 40
#         > Mean quality of the solutions in this iteration : 91196.21704525972
#
#     • Iteration 41
#         > Mean quality of the solutions in this iteration : 90349.81611225882
#
#     • Iteration 42
#         > Mean quality of the solutions in this iteration : 88249.76370007006
#
#     • Iteration 43
#         > Mean quality of the solutions in this iteration : 88823.35401307774
#
#     • Iteration 44
#         > Mean quality of the solutions in this iteration : 88769.0074440161
#
#     • Iteration 45
#         > Mean quality of the solutions in this iteration : 90697.97574898698
#
#     • Iteration 46
#         > Mean quality of the solutions in this iteration : 89030.45035281676
#
#     • Iteration 47
#         > Mean quality of the solutions in this iteration : 90320.47388034571
#         + New best energy: 51332, with the next distance: 623
#
#     • Iteration 48
#         > Mean quality of the solutions in this iteration : 88466.49020263884
#
#     • Iteration 49
#         > Mean quality of the solutions in this iteration : 90288.00514597965
#
#     • Iteration 50
#         > Mean quality of the solutions in this iteration : 88657.48121169205
#
#     • Iteration 51
#         > Mean quality of the solutions in this iteration : 90458.99143467685
#
#     • Iteration 52
#         > Mean quality of the solutions in this iteration : 90586.94233535112
#
#     • Iteration 53
#         > Mean quality of the solutions in this iteration : 90610.36577671766
#
#     • Iteration 54
#         > Mean quality of the solutions in this iteration : 91675.96114967896
#         + New best energy: 50921, with the next distance: 616
#
#     • Iteration 55
#         > Mean quality of the solutions in this iteration : 89582.66157135568
#
#     • Iteration 56
#         > Mean quality of the solutions in this iteration : 88731.66383714406
#
#     • Iteration 57
#         > Mean quality of the solutions in this iteration : 89820.1960609927
#
#     • Iteration 58
#         > Mean quality of the solutions in this iteration : 89089.4518675283
#
#     • Iteration 59
#         > Mean quality of the solutions in this iteration : 89546.2754694415
#
#     • Iteration 60
#         > Mean quality of the solutions in this iteration : 92261.59647319937
#
#     • Iteration 61
#         > Mean quality of the solutions in this iteration : 89799.0846078359
#
#     • Iteration 62
#         > Mean quality of the solutions in this iteration : 90387.92961331086
#
#     • Iteration 63
#         > Mean quality of the solutions in this iteration : 89178.16333401896
#
#     • Iteration 64
#         > Mean quality of the solutions in this iteration : 89997.57941849223
#
#     • Iteration 65
#         > Mean quality of the solutions in this iteration : 90777.07340694331
#
#     • Iteration 66
#         > Mean quality of the solutions in this iteration : 90347.55228029571
#
#     • Iteration 67
#         > Mean quality of the solutions in this iteration : 91016.16808341244
#
#     • Iteration 68
#         > Mean quality of the solutions in this iteration : 90639.34680598456
#
#     • Iteration 69
#         > Mean quality of the solutions in this iteration : 91251.04596107766
#
#     • Iteration 70
#         > Mean quality of the solutions in this iteration : 89715.3758787707
#
#     • Iteration 71
#         > Mean quality of the solutions in this iteration : 89326.61466513822
#         + New best energy: 50404, with the next distance: 595
#
#     • Iteration 72
#         > Mean quality of the solutions in this iteration : 88593.51492766463
#
#     • Iteration 73
#         > Mean quality of the solutions in this iteration : 89376.2002838258
#
#     • Iteration 74
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6888\3130967046.py in <module>
#      94             )
#      95
# ---> 96             solution_energy, solution_arcs, solution_distance, solution_time = bwacs.solve()
#      97             solution_list.append(
#      98                 (solution_energy, solution_arcs, solution_distance, solution_time))
#
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py in solve(self)
#    1248                                                            self.demands_array, self.TARE, self.VEHICLE_CAPACITY, self.K_NUMBER, iteration + 1,
#    1249                                                            self.MAX_ITERATIONS)
# -> 1250                     ls_solution, ls_energies = local_search_model.improve()
#    1251
#    1252                     # We save the LS solution if is better than the current best solution.
#
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\src\local_search\free_bwacs_ls\local_variable_neighborhood_search.py in improve(self)
#     262                                                                              shaking_ratio)
#     263                 vns_solution, vns_quality = self.VNS(shaking_solution.copy(), shaking_quality.copy(), best_global_quality.copy(),
# --> 264                                                      int(((len(self.demands_array) - 1) / 3)), idx_routes)
#     265
#     266                 if vns_quality.sum() < best_global_quality.sum():
#
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\src\local_search\free_bwacs_ls\local_variable_neighborhood_search.py in VNS(self, shaking_solution, shaking_quality, best_global_quality, N, idx_routes)
#     236                                                                                           idx_route, tabu_list)
#     237                 # singleRouteRelocate()
# --> 238                 best_vns_solution, best_vns_quality, tabu_list = self.singleRouteRelocate(best_vns_solution.copy(), best_vns_quality.copy(),
#     239                                                                                           idx_route, tabu_list)
#     240
#
# KeyboardInterrupt:

# %%
# Execution of runs for instances files for RESTRICTED-ANT

instances_with_errors = []
cluster_type = 'kmeans'  # 'kmeans' or 'kmedoids'
ant_type = 'ra'  # 'fa', 'ra' or 'random'

# Validation of folder to save results
if SAVE_RESULTS:
    if not os.path.exists(BASE_RESULTS_FOLDER):
        os.makedirs(BASE_RESULTS_FOLDER)

# Start running the algorithm
for instance in INSTANCES:

    solution_list = []
    results_folder = f'{THIS_EXECUTION_FOLDER}/{instance}'
    file_name = f'{str(instance).lower()}_{ant_type}_{cluster_type}'

    if SAVE_IMGS:
        os.makedirs(
            f'{BASE_RESULTS_FOLDER}/{results_folder}/imgs', exist_ok=True)

    for run in range(RUNS):
        try:
            bwacs = RestrictedBWACS(
                    instance=f'{INSTANCES_FOLDER}/{instance}',
                    max_nodes=999,
                    ant_type='emvrp',
                    cluster_type=cluster_type,
                    metric='euclidian',
                    tare=0.15,
                    max_iterations=50,
                    max_ants=50,
                    start_ant_on_best_nodes=1,
                    # Importance of pheromones trace. Recommended alpha value in: [1, 4]
                    alpha=2,
                    # Importance of distance heuristic information. Recommended beta value in: [2, 5]
                    beta=1,
                    # Importance of energy heuristic information. Recommended gamma value in: [2, 5]
                    gamma=3,
                    # Importance of distances's Savings Algorithm information. Recommended delta value in: [0, 2]
                    delta=1,
                    # Importance of energies's Savings Algorithm information. Recommended eta value in: [0, 2]
                    eta=1,
                    # Importance of vehicle's capacity utilization. Recommended mi value in: [0, 2]
                    mi=0,
                    pheromone_updating_strategy=0,
                    local_ant_update_pheromones=0,
                    best_iteration_update_pheromones=1,
                    best_global_update_pheromones=1,
                    penalize_worst_solution=1,
                    mutate_pheromones_matrix=1,
                    # Evaporation rate of the pheromones by the next function: phoromone =  (1 - p) * pheromone. Recommended value for p: 0.02.
                    p=0.02,
                    # Mutation probability for every row of the pheromones matrix, such as: mutate if (random number between 0 and 1) <= Pm
                    # Recommended value for Pm: 0.3.
                    Pm=0.3,
                    # Mutation intensity for the pheromones matrix. Recommended value for sigma in: [2, 4]
                    sigma=3,
                    # Constant used in Pseudorandom Transition Rule. This is a probability of choice the next node by argmax, define in Ant Colony System.
                    # Recommended value for l0 in: [0.2, 0.4]
                    q0=0.3,
                    # Constant used for a lot of functions, such as: f(.) = H / specific_values.
                    Q=1,
                    # heuristic_type will let you choice what information gotta build the heuristic information matrix
                    # 0 - Only distances data / Best beta: 5
                    # 1 - Only energies data / Best gamma: 5
                    # 2 - Distances data * energies data / Best parameters: 5 - 5
                    # 3 - Only distances data of Savings algorithm / Best delta: 1
                    # 4 - Only energies data of Savings algorithm / Best eta: 2
                    # 5 - Distances data * distances savings data / Best parameters: 4 - 5
                    # 6 - Energies data * energies savings data / Best parameters: 5 - 5
                    # 7 - Distances data * energies data * distances savings data / Best parameters: 3 - 4 - 3
                    # 8 - Distances data * energies data * energies savings data / Best parameters: 3 - 4 - 3
                    # 9 - Distances data * energies data * distances savings data * capacity utilization data / Best parameters: 2 - 4 - 4 - 2
                    # 10 - Distances data * energies data * distances savings data * capacity utilization data / Best parameters: 2 - 4 - 4 - 2
                    # 11 - Distances data * energies data * distances savings data * energies savings data * capacity utilization data / Best parameters: 2 - 4 - 3 - 4 - 1
                    heuristic_type=2,
                    ls_ant_solution=0,
                    ls_final_solution=0,
                    output_sol_img=f'{BASE_RESULTS_FOLDER}/{results_folder}/imgs/{file_name}.png'
            )

            solution_energy, solution_arcs, solution_distance, solution_time = bwacs.solve()
            solution_list.append(
                (solution_energy, solution_arcs, solution_distance, solution_time))
        except Exception as e:
            instances_with_errors.append((instance, e))
            break

    if (len(solution_list) > 0):
        print(f'Solutions for instance {instance}: {solution_list}')
        print(f'{RUNS} runs for instance {instance} finished at {datetime.now().strftime("%Y%m%d_%H%M%S")}')
        print(
            f'Best solution for instance {instance}: {min(solution_list, key=lambda x: x[0])}')
        print(
            f'Worst solution for instance {instance}: {max(solution_list or [], key=lambda x: x[0])}')

        if SAVE_RESULTS:
            os.makedirs(
                f'{BASE_RESULTS_FOLDER}/{results_folder}', exist_ok=True)
            save_results_on_file(f'{BASE_RESULTS_FOLDER}/{results_folder}', file_name, ant_type, cluster_type,
                                 solution_list, instance, 'csv', 'energy,arcs,distance,time(ms)')

if len(instances_with_errors) > 0:
    print(f'Instances with errors: {instances_with_errors}')
    os.makedirs(f'{BASE_RESULTS_FOLDER}/{results_folder}', exist_ok=True)
    error_file = open(
        f'{BASE_RESULTS_FOLDER}/{THIS_EXECUTION_FOLDER}/error_instances.txt', 'a')
    for instance, error in instances_with_errors:
        error_file.write(f'{instance}: {error}\n')
    error_file.close()
# Out:
# • INICIALIZANDO ALGORITMO •
# ------------------------------
#
# • PARAMETROS DE LA INSTANCIA:
#
#     > Nodos y demandas: {0: 0, 1: 7, 2: 30, 3: 16, 4: 9, 5: 21, 6: 15, 7: 19, 8: 23, 9: 11, 10: 5, 11: 19, 12: 29, 13: 23, 14: 21, 15: 10, 16: 15, 17: 3, 18: 41, 19: 9, 20: 28, 21: 8, 22: 8, 23: 16, 24: 10, 25: 28, 26: 7, 27: 15, 28: 14, 29: 6, 30: 19, 31: 11, 32: 12, 33: 23, 34: 26, 35: 17, 36: 6, 37: 9, 38: 15, 39: 14, 40: 7, 41: 27, 42: 13, 43: 11, 44: 16, 45: 10, 46: 5, 47: 25, 48: 17, 49: 18, 50: 10}
#     > Demanda total: 777
#     > Capacidad vehiculo: 160
#     > K-Optimo: 5
#     > Tightnessratio: 0.97125
#
# • INICIANDO CLUSTERIZACIÓN:
#
#     > CLUSTER TYPE: KMEANS
#     > ITERACIÓN 1
#         - Centroides actuales: [array([57, 58]), array([17, 33]), array([10, 17]), array([61, 33]), array([ 7, 38])]
#         - Nodos sin asignar: [ 7 30], [23 11]
#         - Mejor costo anterior: inf
#         - Costo total actual: 9739.5597891085
#
#     > ITERACIÓN 2
#         - Centroides actuales: [array([37., 69.]), array([29.11111111, 31.44444444]), array([22.77777778, 13.55555556]), array([54.4, 31.2]), array([16.8, 53.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 9739.5597891085
#         - Costo total actual: 9469.008712103712
#
#     > ITERACIÓN 3
#         - Centroides actuales: [array([41.3, 59.2]), array([32.44444444, 33.77777778]), array([21.22222222, 14.88888889]), array([46., 10.]), array([20.4, 53.5])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 10376.00191633337
#
#     > ITERACIÓN 4
#         - Centroides actuales: [array([63., 69.]), array([39.3, 34.7]), array([21., 21.]), array([50.        , 22.33333333]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 9382.963165716292
#
#     > ITERACIÓN 5
#         - Centroides actuales: [array([52.5, 58.6]), array([39.8, 38.5]), array([18., 19.]), array([50.        , 21.44444444]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 9382.963165716292
#         - Costo total actual: 9131.213913563224
#
#     > ITERACIÓN 6
#         - Centroides actuales: [array([27., 68.]), array([40.3, 40.1]), array([20.8, 21.9]), array([48.1, 25.5]), array([ 5., 64.])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 12447.104568066417
#
#     > ITERACIÓN 7
#         - Centroides actuales: [array([40.54545455, 57.        ]), array([44.6, 42.5]), array([20. , 19.7]), array([50.7, 25. ]), array([17.        , 50.11111111])]
#         - Nodos sin asignar: [12], [23]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9205.552639738571
#
#     > ITERACIÓN 8
#         - Centroides actuales: [array([43.8, 61.5]), array([47.        , 39.45454545]), array([ 5., 25.]), array([50.11111111, 23.66666667]), array([15.66666667, 51.77777778])]
#         - Nodos sin asignar: [11], [29]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9274.450376400218
#
#     > ITERACIÓN 9
#         - Centroides actuales: [array([43.72727273, 58.54545455]), array([31., 32.]), array([12.25, 21.  ]), array([45.18181818, 21.36363636]), array([17.66666667, 51.11111111])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 10115.12837053417
#
#     > ITERACIÓN 10
#         - Centroides actuales: [array([44.4, 57.2]), array([40.09090909, 35.54545455]), array([12.25, 21.  ]), array([49. , 22.3]), array([25.36363636, 54.18181818])]
#         - Nodos sin asignar: [43], [16]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 8770.75270035537
#
#     > ITERACIÓN 11
#         - Centroides actuales: [array([51.09090909, 58.        ]), array([39.3, 35.5]), array([30., 15.]), array([50.        , 21.44444444]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9769.457396640944
#
#     > ITERACIÓN 12
#         - Centroides actuales: [array([51.44444444, 58.55555556]), array([40.4, 40.7]), array([24.5, 18.5]), array([44.1, 23.5]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9149.19296884423
#
#     > ITERACIÓN 13
#         - Centroides actuales: [array([27., 68.]), array([38.8, 42.6]), array([21.4, 22.6]), array([49. , 22.3]), array([ 5., 64.])]
#         - Nodos sin asignar: [20], [8]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 11671.139732542391
#
#     > ITERACIÓN 14
#         - Centroides actuales: [array([43.9, 63.2]), array([62., 42.]), array([20. , 19.7]), array([49. , 22.3]), array([16.55555556, 48.44444444])]
#         - Nodos sin asignar: [39], [7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10696.56634254118
#
#     > ITERACIÓN 15
#         - Centroides actuales: [array([41.16666667, 61.58333333]), array([47.77777778, 39.        ]), array([5., 6.]), array([46. , 22.2]), array([18.66666667, 49.        ])]
#         - Nodos sin asignar: [46], [25]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10035.503670792263
#
#     > ITERACIÓN 16
#         - Centroides actuales: [array([45.1, 62.9]), array([51.5, 40.5]), array([16.44444444, 18.66666667]), array([44. , 21.1]), array([25., 32.])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10623.636803568075
#
#     > ITERACIÓN 17
#         - Centroides actuales: [array([41.41666667, 60.58333333]), array([53.6, 37.4]), array([15.22222222, 25.44444444]), array([40.        , 28.88888889]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9746.613717133847
#
#     > ITERACIÓN 18
#         - Centroides actuales: [array([44.9, 59.3]), array([54.63636364, 37.09090909]), array([15.88888889, 20.55555556]), array([46., 10.]), array([15.33333333, 54.        ])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9550.93543363689
#
#     > ITERACIÓN 19
#         - Centroides actuales: [array([63., 69.]), array([54.8, 40. ]), array([18.88888889, 22.33333333]), array([38.5, 18.3]), array([17.3, 50.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10439.904257073627
#
#     > ITERACIÓN 20
#         - Centroides actuales: [array([47.3, 61. ]), array([48.09090909, 35.36363636]), array([18.88888889, 24.22222222]), array([41.2, 19.9]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24 25], [28  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 8306.319175559167
#
#     > ITERACIÓN 21
#         - Centroides actuales: [array([50. , 59.6]), array([51.4, 36.3]), array([ 7., 38.]), array([36.9, 17.7]), array([27., 68.])]
#         - Nodos sin asignar: [38 18], [14  9]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 10173.537298092959
#
#     > ITERACIÓN 22
#         - Centroides actuales: [array([50.11111111, 56.33333333]), array([47.18181818, 33.54545455]), array([15.25, 37.75]), array([13., 13.]), array([23.5, 55.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9888.028925395214
#
#     > ITERACIÓN 23
#         - Centroides actuales: [array([51.18181818, 55.90909091]), array([50.5, 32.6]), array([17.55555556, 38.66666667]), array([22.4, 16.7]), array([30.2, 49.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8779.285862604613
#
#     > ITERACIÓN 24
#         - Centroides actuales: [array([52.81818182, 52.63636364]), array([46., 10.]), array([18.83333333, 37.33333333]), array([21.63636364, 16.63636364]), array([24.18181818, 55.09090909])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11160.760494587392
#
#     > ITERACIÓN 25
#         - Centroides actuales: [array([53.2, 50. ]), array([48.63636364, 29.63636364]), array([20.57142857, 34.57142857]), array([23.09090909, 23.90909091]), array([26.09090909, 56.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9326.960082949558
#
#     > ITERACIÓN 26
#         - Centroides actuales: [array([53.9, 53.2]), array([47.5, 32.3]), array([18.85714286, 38.28571429]), array([23.66666667, 16.08333333]), array([29.27272727, 57.63636364])]
#         - Nodos sin asignar: [12 32], [23 23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8422.104191179695
#
#     > ITERACIÓN 27
#         - Centroides actuales: [array([49.54545455, 51.27272727]), array([46., 10.]), array([ 5., 25.]), array([25.33333333, 16.88888889]), array([25.6, 57. ])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11012.655751743518
#
#     > ITERACIÓN 28
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([49. , 22.3]), array([ 9.85714286, 24.85714286]), array([35.27272727, 33.27272727]), array([23.63636364, 59.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9547.94009204571
#
#     > ITERACIÓN 29
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([52.27272727, 29.54545455]), array([12.        , 27.71428571]), array([28.90909091, 26.54545455]), array([23. , 60.4])]
#         - Nodos sin asignar: [27 35], [14  6]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8066.528567941032
#
#     > ITERACIÓN 30
#         - Centroides actuales: [array([63., 69.]), array([52.45454545, 26.45454545]), array([12.        , 27.71428571]), array([27.9, 22.5]), array([21.7, 58.5])]
#         - Nodos sin asignar: [32 10], [23 19]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9162.6705524307
#
#     > ITERACIÓN 31
#         - Centroides actuales: [array([48.18181818, 53.81818182]), array([42., 41.]), array([12.        , 27.71428571]), array([31.3, 22.9]), array([23.18181818, 55.81818182])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9781.030433449172
#
#     > ITERACIÓN 32
#         - Centroides actuales: [array([47.90909091, 55.09090909]), array([49.63636364, 36.54545455]), array([12.71428571, 25.28571429]), array([31.5, 18.1]), array([25.        , 53.09090909])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8647.195431821801
#
#     > ITERACIÓN 33
#         - Centroides actuales: [array([63., 69.]), array([50.5, 32.6]), array([12.        , 27.71428571]), array([31.90909091, 17.36363636]), array([22.72727273, 54.63636364])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10224.697698766111
#
#     > ITERACIÓN 34
#         - Centroides actuales: [array([53.09090909, 54.63636364]), array([48.63636364, 34.63636364]), array([12.71428571, 25.28571429]), array([29.09090909, 22.27272727]), array([22.4, 54.6])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8205.405893565472
#
#     > ITERACIÓN 35
#         - Centroides actuales: [array([51.18181818, 57.45454545]), array([59., 15.]), array([12.        , 27.71428571]), array([29.2, 17.6]), array([22.63636364, 55.18181818])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9840.425181254781
#
#     > ITERACIÓN 36
#         - Centroides actuales: [array([51.6, 56.2]), array([53. , 31.5]), array([12.71428571, 25.28571429]), array([32.33333333, 23.83333333]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9209.872196275994
#
#     > ITERACIÓN 37
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([53.27272727, 32.09090909]), array([12.        , 27.71428571]), array([46., 10.]), array([18.5, 52.2])]
#         - Nodos sin asignar: [18 39], [9 7]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8682.729335656946
#
#     > ITERACIÓN 38
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\restricted_bwacs_model.py:410: RuntimeWarning: divide by zero encountered in true_divide
#   _distance_matrix = self.np.divide(1, self.distances_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\restricted_bwacs_model.py:411: RuntimeWarning: divide by zero encountered in true_divide
#   _energy_matrix = self.np.divide(1, self.energies_matrix)
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([5., 6.]), array([38.5, 18.1]), array([19.2, 55.8])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9938.838033288544
#
#     > ITERACIÓN 39
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([12.25, 21.  ]), array([59., 15.]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24 42], [28 11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8844.914022470824
#
#     > ITERACIÓN 40
#         - Centroides actuales: [array([48.36363636, 57.72727273]), array([46.6, 36.5]), array([ 7., 38.]), array([45.77777778, 18.77777778]), array([ 5., 64.])]
#         - Nodos sin asignar: [40], [27]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10771.024281503887
#
#     > ITERACIÓN 41
#         - Centroides actuales: [array([48.18181818, 52.27272727]), array([46.33333333, 36.44444444]), array([10., 17.]), array([42. , 17.4]), array([20.4, 53.5])]
#         - Nodos sin asignar: [30], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9760.871029384165
#
#     > ITERACIÓN 42
#         - Centroides actuales: [array([37., 69.]), array([48.6, 34.4]), array([19.88888889, 25.66666667]), array([35.8, 20.2]), array([19.2, 55.8])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9867.190655216931
#
#     > Mejor Clusterización: [array([ 2, 16, 29, 11, 22, 32, 20,  1,  3, 35], dtype=int64), array([ 9, 49, 30, 50, 10, 38, 34, 21, 39, 33, 45], dtype=int64), array([18, 13,  4, 41, 25, 14, 19], dtype=int64), array([17, 37, 12, 47, 44,  5, 15, 46, 42, 40], dtype=int64), array([48,  7, 23,  8, 26,  6, 27, 31, 24, 43], dtype=int64)], con costo final: 8066.528567941032, nodos sin asignar: [28 36]
#     > Mejor Clusterización (Contraint): [array([ 2, 29, 20, 16, 21, 22,  3, 11, 35, 36], dtype=int64), array([49,  9, 38,  5, 10, 30, 50, 34, 39, 43], dtype=int64), array([18, 47, 12, 14, 46, 25, 24], dtype=int64), array([ 4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], dtype=int64), array([48,  8, 27, 23,  6,  7,  1, 26, 32, 31, 28], dtype=int64)], con costo final: 9326.960082949558, nodos sin asignar: []
#     --- 0.2219996452331543 seconds ---
#
#     > CLUSTERS
#          - Cluster 0: [2, 29, 20, 16, 21, 22, 3, 11, 35, 36], con demanda final: 153
#          - Cluster 1: [49, 9, 38, 5, 10, 30, 50, 34, 39, 43], con demanda final: 150
#          - Cluster 2: [18, 47, 12, 14, 46, 25, 24], con demanda final: 159
#          - Cluster 3: [4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], con demanda final: 159
#          - Cluster 4: [48, 8, 27, 23, 6, 7, 1, 26, 32, 31, 28], con demanda final: 156
#          - Nodos totales: 50
# • INICIANDO ACO(BWACS):
# [0.00012046491438470069, 0.0001278472732709808, 0.000211546303599152, 0.00010880283273445991, 0.0001621931923780779]
# [0.001204649143847007, 0.0012784727327098079, 0.00211546303599152, 0.0010880283273445991, 0.001621931923780779]
#
#     • CLUSTER 1
#         > Iteración 1
# 0
#             - Mejor costo para cluster 1: 11015.220151005386
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 6
#         > Iteración 7
# 8
#         > Iteración 8
# 8
#         > Iteración 9
# 9
#         > Iteración 10
# 9
#         > Iteración 11
# 9
#         > Iteración 12
# 9
#         > Iteración 13
# 9
#         > Iteración 14
# 9
#         > Iteración 15
# 9
#         > Iteración 16
# 9
#         > Iteración 17
# 0
#             - Mejor costo para cluster 1: 10853.930168890378
#         > Iteración 18
# 0
#         > Iteración 19
# 0
#         > Iteración 20
# 0
#         > Iteración 21
# 2
#         > Iteración 22
# 7
#         > Iteración 23
# 9
#         > Iteración 24
# 9
#         > Iteración 25
# 9
#         > Iteración 26
# 9
#         > Iteración 27
# 9
#         > Iteración 28
# 9
#         > Iteración 29
# 9
#         > Iteración 30
# 9
#         > Iteración 31
# 9
#         > Iteración 32
# 9
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 1
#         > Iteración 39
# 2
#         > Iteración 40
# 8
#         > Iteración 41
# 9
#         > Iteración 42
# 9
#         > Iteración 43
# 9
#         > Iteración 44
# 9
#         > Iteración 45
# 9
#         > Iteración 46
# 9
#             - Mejor costo para cluster 1: 10845.149543008085
#         > Iteración 47
# 7
#         > Iteración 48
# 7
#         > Iteración 49
# 7
#         > Iteración 50
# 7
#
#     • CLUSTER 2
#         > Iteración 1
# 0
#             - Mejor costo para cluster 2: 21162.52656304934
#         > Iteración 2
# 0
#             - Mejor costo para cluster 2: 18172.2382097645
#         > Iteración 3
# 0
#             - Mejor costo para cluster 2: 17674.811739653644
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#         > Iteración 7
# 0
#         > Iteración 8
# 0
#             - Mejor costo para cluster 2: 14193.830479458833
#         > Iteración 9
# 0
#         > Iteración 10
# 1
#         > Iteración 11
# 2
#         > Iteración 12
# 2
#         > Iteración 13
# 2
#         > Iteración 14
# 3
#         > Iteración 15
# 6
#         > Iteración 16
# 6
#         > Iteración 17
# 8
#         > Iteración 18
# 8
#         > Iteración 19
# 9
#         > Iteración 20
# 9
#         > Iteración 21
# 9
#         > Iteración 22
# 9
#         > Iteración 23
# 9
#         > Iteración 24
# 0
#         > Iteración 25
# 0
#         > Iteración 26
# 0
#         > Iteración 27
# 0
#         > Iteración 28
# 0
#         > Iteración 29
# 0
#         > Iteración 30
# 0
#         > Iteración 31
# 2
#             - Mejor costo para cluster 2: 13240.376671020207
#         > Iteración 32
# 6
#         > Iteración 33
# 6
#         > Iteración 34
# 6
#         > Iteración 35
# 6
#         > Iteración 36
# 6
#         > Iteración 37
# 7
#         > Iteración 38
# 6
#         > Iteración 39
# 6
#         > Iteración 40
# 6
#         > Iteración 41
# 9
#         > Iteración 42
# 9
#         > Iteración 43
# 9
#         > Iteración 44
# 9
#         > Iteración 45
# 9
#         > Iteración 46
# 9
#         > Iteración 47
# 0
#         > Iteración 48
# 0
#         > Iteración 49
# 0
#         > Iteración 50
# 0
#
#     • CLUSTER 3
#         > Iteración 1
# 0
#             - Mejor costo para cluster 3: 6979.825091096387
#         > Iteración 2
# 0
#             - Mejor costo para cluster 3: 5809.339997924701
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 1
#         > Iteración 7
# 3
#         > Iteración 8
# 5
#         > Iteración 9
# 6
#         > Iteración 10
# 6
#         > Iteración 11
# 6
#         > Iteración 12
# 6
#         > Iteración 13
# 6
#         > Iteración 14
# 6
#         > Iteración 15
# 6
#         > Iteración 16
# 6
#         > Iteración 17
# 6
#         > Iteración 18
# 0
#         > Iteración 19
# 0
#         > Iteración 20
# 0
#         > Iteración 21
# 0
#         > Iteración 22
# 6
#         > Iteración 23
# 6
#         > Iteración 24
# 6
#         > Iteración 25
# 6
#         > Iteración 26
# 6
#         > Iteración 27
# 6
#         > Iteración 28
# 6
#         > Iteración 29
# 6
#         > Iteración 30
# 6
#         > Iteración 31
# 6
#         > Iteración 32
# 6
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 1
#         > Iteración 39
# 5
#         > Iteración 40
# 6
#         > Iteración 41
# 6
#         > Iteración 42
# 6
#         > Iteración 43
# 6
#         > Iteración 44
# 6
#         > Iteración 45
# 6
#         > Iteración 46
# 6
#         > Iteración 47
# 6
#         > Iteración 48
# 0
#         > Iteración 49
# 0
#         > Iteración 50
# 0
#
#     • CLUSTER 4
#         > Iteración 1
# 0
#             - Mejor costo para cluster 4: 16150.196733391771
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#             - Mejor costo para cluster 4: 16063.072437225022
#         > Iteración 6
# 0
#         > Iteración 7
# 1
#         > Iteración 8
# 2
#         > Iteración 9
# 2
#         > Iteración 10
# 2
#         > Iteración 11
# 3
#         > Iteración 12
# 5
#         > Iteración 13
# 8
#         > Iteración 14
# 11
#         > Iteración 15
# 11
#         > Iteración 16
# 11
#         > Iteración 17
# 11
#         > Iteración 18
# 11
#         > Iteración 19
# 11
#             - Mejor costo para cluster 4: 14626.945180799641
#         > Iteración 20
# 4
#         > Iteración 21
# 4
#         > Iteración 22
# 4
#         > Iteración 23
# 5
#         > Iteración 24
# 8
#         > Iteración 25
# 9
#         > Iteración 26
# 10
#         > Iteración 27
# 10
#         > Iteración 28
# 11
#         > Iteración 29
# 11
#         > Iteración 30
# 11
#         > Iteración 31
# 11
#         > Iteración 32
# 13
#         > Iteración 33
# 15
#         > Iteración 34
# 15
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 0
#         > Iteración 39
# 0
#         > Iteración 40
# 2
#         > Iteración 41
# 2
#         > Iteración 42
# 6
#         > Iteración 43
# 9
#         > Iteración 44
# 11
#         > Iteración 45
# 11
#         > Iteración 46
# 11
#         > Iteración 47
# 11
#         > Iteración 48
# 11
#         > Iteración 49
# 11
#         > Iteración 50
# 0
#
#     • CLUSTER 5
#         > Iteración 1
# 0
#             - Mejor costo para cluster 5: 13833.887462778795
#         > Iteración 2
# 0
#             - Mejor costo para cluster 5: 12048.209674518806
#         > Iteración 3
# 0
#             - Mejor costo para cluster 5: 12023.910627321944
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#             - Mejor costo para cluster 5: 11675.248088668153
#         > Iteración 6
# 0
#         > Iteración 7
# 0
#         > Iteración 8
# 0
#         > Iteración 9
# 0
#         > Iteración 10
# 1
#         > Iteración 11
# 1
#         > Iteración 12
# 2
#         > Iteración 13
# 2
#         > Iteración 14
# 7
#         > Iteración 15
# 9
#         > Iteración 16
# 9
#             - Mejor costo para cluster 5: 11377.142140807868
#         > Iteración 17
# 6
#         > Iteración 18
# 7
#         > Iteración 19
# 7
#             - Mejor costo para cluster 5: 11237.646746764216
#         > Iteración 20
# 6
#         > Iteración 21
# 6
#         > Iteración 22
# 7
#         > Iteración 23
# 7
#         > Iteración 24
# 7
#         > Iteración 25
# 7
#         > Iteración 26
# 7
#         > Iteración 27
# 7
#         > Iteración 28
# 8
#             - Mejor costo para cluster 5: 10106.639991832935
#         > Iteración 29
# 4
#         > Iteración 30
# 5
#         > Iteración 31
# 6
#         > Iteración 32
# 8
#         > Iteración 33
# 8
#         > Iteración 34
# 8
#         > Iteración 35
# 8
#         > Iteración 36
# 8
#         > Iteración 37
# 10
#         > Iteración 38
# 10
#         > Iteración 39
# 10
#         > Iteración 40
# 10
#         > Iteración 41
# 10
#         > Iteración 42
# 11
#         > Iteración 43
# 11
#         > Iteración 44
# 0
#         > Iteración 45
# 0
#         > Iteración 46
# 0
#         > Iteración 47
# 0
#         > Iteración 48
# 0
#         > Iteración 49
# 0
#         > Iteración 50
# 0
#
#  RUTAS OBTENIDAS POR LA COLONIA
# > RUTA 0: [0, 21, 29, 20, 35, 36, 3, 22, 2, 16, 11, 0], con demanda final: 153
# > RUTA 1: [0, 43, 49, 9, 50, 34, 30, 39, 10, 5, 38, 0], con demanda final: 150
# > RUTA 2: [0, 24, 14, 25, 18, 47, 12, 46, 0], con demanda final: 159
# > RUTA 3: [0, 17, 37, 15, 45, 33, 44, 42, 40, 19, 41, 13, 4, 0], con demanda final: 159
# > RUTA 4: [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0], con demanda final: 156
# > Energia total final: 54628.45138458557
# > Distancia total final: inf
#
# --- 0.3549995422363281 seconds ---
# • INICIALIZANDO ALGORITMO •
# ------------------------------
#
# • PARAMETROS DE LA INSTANCIA:
#
#     > Nodos y demandas: {0: 0, 1: 7, 2: 30, 3: 16, 4: 9, 5: 21, 6: 15, 7: 19, 8: 23, 9: 11, 10: 5, 11: 19, 12: 29, 13: 23, 14: 21, 15: 10, 16: 15, 17: 3, 18: 41, 19: 9, 20: 28, 21: 8, 22: 8, 23: 16, 24: 10, 25: 28, 26: 7, 27: 15, 28: 14, 29: 6, 30: 19, 31: 11, 32: 12, 33: 23, 34: 26, 35: 17, 36: 6, 37: 9, 38: 15, 39: 14, 40: 7, 41: 27, 42: 13, 43: 11, 44: 16, 45: 10, 46: 5, 47: 25, 48: 17, 49: 18, 50: 10}
#     > Demanda total: 777
#     > Capacidad vehiculo: 160
#     > K-Optimo: 5
#     > Tightnessratio: 0.97125
#
# • INICIANDO CLUSTERIZACIÓN:
#
#     > CLUSTER TYPE: KMEANS
#     > ITERACIÓN 1
#         - Centroides actuales: [array([57, 58]), array([17, 33]), array([10, 17]), array([61, 33]), array([ 7, 38])]
#         - Nodos sin asignar: [ 7 30], [23 11]
#         - Mejor costo anterior: inf
#         - Costo total actual: 9739.5597891085
#
#     > ITERACIÓN 2
#         - Centroides actuales: [array([37., 69.]), array([29.11111111, 31.44444444]), array([22.77777778, 13.55555556]), array([54.4, 31.2]), array([16.8, 53.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 9739.5597891085
#         - Costo total actual: 9469.008712103712
#
#     > ITERACIÓN 3
#         - Centroides actuales: [array([41.3, 59.2]), array([32.44444444, 33.77777778]), array([21.22222222, 14.88888889]), array([46., 10.]), array([20.4, 53.5])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 10376.00191633337
#
#     > ITERACIÓN 4
#         - Centroides actuales: [array([63., 69.]), array([39.3, 34.7]), array([21., 21.]), array([50.        , 22.33333333]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 9382.963165716292
#
#     > ITERACIÓN 5
#         - Centroides actuales: [array([52.5, 58.6]), array([39.8, 38.5]), array([18., 19.]), array([50.        , 21.44444444]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 9382.963165716292
#         - Costo total actual: 9131.213913563224
#
#     > ITERACIÓN 6
#         - Centroides actuales: [array([27., 68.]), array([40.3, 40.1]), array([20.8, 21.9]), array([48.1, 25.5]), array([ 5., 64.])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 12447.104568066417
#
#     > ITERACIÓN 7
#         - Centroides actuales: [array([40.54545455, 57.        ]), array([44.6, 42.5]), array([20. , 19.7]), array([50.7, 25. ]), array([17.        , 50.11111111])]
#         - Nodos sin asignar: [12], [23]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9205.552639738571
#
#     > ITERACIÓN 8
#         - Centroides actuales: [array([43.8, 61.5]), array([47.        , 39.45454545]), array([ 5., 25.]), array([50.11111111, 23.66666667]), array([15.66666667, 51.77777778])]
#         - Nodos sin asignar: [11], [29]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9274.450376400218
#
#     > ITERACIÓN 9
#         - Centroides actuales: [array([43.72727273, 58.54545455]), array([31., 32.]), array([12.25, 21.  ]), array([45.18181818, 21.36363636]), array([17.66666667, 51.11111111])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 10115.12837053417
#
#     > ITERACIÓN 10
#         - Centroides actuales: [array([44.4, 57.2]), array([40.09090909, 35.54545455]), array([12.25, 21.  ]), array([49. , 22.3]), array([25.36363636, 54.18181818])]
#         - Nodos sin asignar: [43], [16]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 8770.75270035537
#
#     > ITERACIÓN 11
#         - Centroides actuales: [array([51.09090909, 58.        ]), array([39.3, 35.5]), array([30., 15.]), array([50.        , 21.44444444]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9769.457396640944
#
#     > ITERACIÓN 12
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\restricted_bwacs_model.py:410: RuntimeWarning: divide by zero encountered in true_divide
#   _distance_matrix = self.np.divide(1, self.distances_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\restricted_bwacs_model.py:411: RuntimeWarning: divide by zero encountered in true_divide
#   _energy_matrix = self.np.divide(1, self.energies_matrix)
#         - Centroides actuales: [array([51.44444444, 58.55555556]), array([40.4, 40.7]), array([24.5, 18.5]), array([44.1, 23.5]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9149.19296884423
#
#     > ITERACIÓN 13
#         - Centroides actuales: [array([27., 68.]), array([38.8, 42.6]), array([21.4, 22.6]), array([49. , 22.3]), array([ 5., 64.])]
#         - Nodos sin asignar: [20], [8]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 11671.139732542391
#
#     > ITERACIÓN 14
#         - Centroides actuales: [array([43.9, 63.2]), array([62., 42.]), array([20. , 19.7]), array([49. , 22.3]), array([16.55555556, 48.44444444])]
#         - Nodos sin asignar: [39], [7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10696.56634254118
#
#     > ITERACIÓN 15
#         - Centroides actuales: [array([41.16666667, 61.58333333]), array([47.77777778, 39.        ]), array([5., 6.]), array([46. , 22.2]), array([18.66666667, 49.        ])]
#         - Nodos sin asignar: [46], [25]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10035.503670792263
#
#     > ITERACIÓN 16
#         - Centroides actuales: [array([45.1, 62.9]), array([51.5, 40.5]), array([16.44444444, 18.66666667]), array([44. , 21.1]), array([25., 32.])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10623.636803568075
#
#     > ITERACIÓN 17
#         - Centroides actuales: [array([41.41666667, 60.58333333]), array([53.6, 37.4]), array([15.22222222, 25.44444444]), array([40.        , 28.88888889]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9746.613717133847
#
#     > ITERACIÓN 18
#         - Centroides actuales: [array([44.9, 59.3]), array([54.63636364, 37.09090909]), array([15.88888889, 20.55555556]), array([46., 10.]), array([15.33333333, 54.        ])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9550.93543363689
#
#     > ITERACIÓN 19
#         - Centroides actuales: [array([63., 69.]), array([54.8, 40. ]), array([18.88888889, 22.33333333]), array([38.5, 18.3]), array([17.3, 50.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10439.904257073627
#
#     > ITERACIÓN 20
#         - Centroides actuales: [array([47.3, 61. ]), array([48.09090909, 35.36363636]), array([18.88888889, 24.22222222]), array([41.2, 19.9]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24 25], [28  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 8306.319175559167
#
#     > ITERACIÓN 21
#         - Centroides actuales: [array([50. , 59.6]), array([51.4, 36.3]), array([ 7., 38.]), array([36.9, 17.7]), array([27., 68.])]
#         - Nodos sin asignar: [38 18], [14  9]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 10173.537298092959
#
#     > ITERACIÓN 22
#         - Centroides actuales: [array([50.11111111, 56.33333333]), array([47.18181818, 33.54545455]), array([15.25, 37.75]), array([13., 13.]), array([23.5, 55.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9888.028925395214
#
#     > ITERACIÓN 23
#         - Centroides actuales: [array([51.18181818, 55.90909091]), array([50.5, 32.6]), array([17.55555556, 38.66666667]), array([22.4, 16.7]), array([30.2, 49.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8779.285862604613
#
#     > ITERACIÓN 24
#         - Centroides actuales: [array([52.81818182, 52.63636364]), array([46., 10.]), array([18.83333333, 37.33333333]), array([21.63636364, 16.63636364]), array([24.18181818, 55.09090909])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11160.760494587392
#
#     > ITERACIÓN 25
#         - Centroides actuales: [array([53.2, 50. ]), array([48.63636364, 29.63636364]), array([20.57142857, 34.57142857]), array([23.09090909, 23.90909091]), array([26.09090909, 56.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9326.960082949558
#
#     > ITERACIÓN 26
#         - Centroides actuales: [array([53.9, 53.2]), array([47.5, 32.3]), array([18.85714286, 38.28571429]), array([23.66666667, 16.08333333]), array([29.27272727, 57.63636364])]
#         - Nodos sin asignar: [12 32], [23 23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8422.104191179695
#
#     > ITERACIÓN 27
#         - Centroides actuales: [array([49.54545455, 51.27272727]), array([46., 10.]), array([ 5., 25.]), array([25.33333333, 16.88888889]), array([25.6, 57. ])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11012.655751743518
#
#     > ITERACIÓN 28
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([49. , 22.3]), array([ 9.85714286, 24.85714286]), array([35.27272727, 33.27272727]), array([23.63636364, 59.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9547.94009204571
#
#     > ITERACIÓN 29
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([52.27272727, 29.54545455]), array([12.        , 27.71428571]), array([28.90909091, 26.54545455]), array([23. , 60.4])]
#         - Nodos sin asignar: [27 35], [14  6]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8066.528567941032
#
#     > ITERACIÓN 30
#         - Centroides actuales: [array([63., 69.]), array([52.45454545, 26.45454545]), array([12.        , 27.71428571]), array([27.9, 22.5]), array([21.7, 58.5])]
#         - Nodos sin asignar: [32 10], [23 19]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9162.6705524307
#
#     > ITERACIÓN 31
#         - Centroides actuales: [array([48.18181818, 53.81818182]), array([42., 41.]), array([12.        , 27.71428571]), array([31.3, 22.9]), array([23.18181818, 55.81818182])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9781.030433449172
#
#     > ITERACIÓN 32
#         - Centroides actuales: [array([47.90909091, 55.09090909]), array([49.63636364, 36.54545455]), array([12.71428571, 25.28571429]), array([31.5, 18.1]), array([25.        , 53.09090909])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8647.195431821801
#
#     > ITERACIÓN 33
#         - Centroides actuales: [array([63., 69.]), array([50.5, 32.6]), array([12.        , 27.71428571]), array([31.90909091, 17.36363636]), array([22.72727273, 54.63636364])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10224.697698766111
#
#     > ITERACIÓN 34
#         - Centroides actuales: [array([53.09090909, 54.63636364]), array([48.63636364, 34.63636364]), array([12.71428571, 25.28571429]), array([29.09090909, 22.27272727]), array([22.4, 54.6])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8205.405893565472
#
#     > ITERACIÓN 35
#         - Centroides actuales: [array([51.18181818, 57.45454545]), array([59., 15.]), array([12.        , 27.71428571]), array([29.2, 17.6]), array([22.63636364, 55.18181818])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9840.425181254781
#
#     > ITERACIÓN 36
#         - Centroides actuales: [array([51.6, 56.2]), array([53. , 31.5]), array([12.71428571, 25.28571429]), array([32.33333333, 23.83333333]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9209.872196275994
#
#     > ITERACIÓN 37
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([53.27272727, 32.09090909]), array([12.        , 27.71428571]), array([46., 10.]), array([18.5, 52.2])]
#         - Nodos sin asignar: [18 39], [9 7]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8682.729335656946
#
#     > ITERACIÓN 38
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([5., 6.]), array([38.5, 18.1]), array([19.2, 55.8])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9938.838033288544
#
#     > ITERACIÓN 39
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([12.25, 21.  ]), array([59., 15.]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24 42], [28 11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8844.914022470824
#
#     > ITERACIÓN 40
#         - Centroides actuales: [array([48.36363636, 57.72727273]), array([46.6, 36.5]), array([ 7., 38.]), array([45.77777778, 18.77777778]), array([ 5., 64.])]
#         - Nodos sin asignar: [40], [27]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10771.024281503887
#
#     > ITERACIÓN 41
#         - Centroides actuales: [array([48.18181818, 52.27272727]), array([46.33333333, 36.44444444]), array([10., 17.]), array([42. , 17.4]), array([20.4, 53.5])]
#         - Nodos sin asignar: [30], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9760.871029384165
#
#     > ITERACIÓN 42
#         - Centroides actuales: [array([37., 69.]), array([48.6, 34.4]), array([19.88888889, 25.66666667]), array([35.8, 20.2]), array([19.2, 55.8])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9867.190655216931
#
#     > Mejor Clusterización: [array([ 2, 16, 29, 11, 22, 32, 20,  1,  3, 35], dtype=int64), array([ 9, 49, 30, 50, 10, 38, 34, 21, 39, 33, 45], dtype=int64), array([18, 13,  4, 41, 25, 14, 19], dtype=int64), array([17, 37, 12, 47, 44,  5, 15, 46, 42, 40], dtype=int64), array([48,  7, 23,  8, 26,  6, 27, 31, 24, 43], dtype=int64)], con costo final: 8066.528567941032, nodos sin asignar: [28 36]
#     > Mejor Clusterización (Contraint): [array([ 2, 29, 20, 16, 21, 22,  3, 11, 35, 36], dtype=int64), array([49,  9, 38,  5, 10, 30, 50, 34, 39, 43], dtype=int64), array([18, 47, 12, 14, 46, 25, 24], dtype=int64), array([ 4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], dtype=int64), array([48,  8, 27, 23,  6,  7,  1, 26, 32, 31, 28], dtype=int64)], con costo final: 9326.960082949558, nodos sin asignar: []
#     --- 0.21200037002563477 seconds ---
#
#     > CLUSTERS
#          - Cluster 0: [2, 29, 20, 16, 21, 22, 3, 11, 35, 36], con demanda final: 153
#          - Cluster 1: [49, 9, 38, 5, 10, 30, 50, 34, 39, 43], con demanda final: 150
#          - Cluster 2: [18, 47, 12, 14, 46, 25, 24], con demanda final: 159
#          - Cluster 3: [4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], con demanda final: 159
#          - Cluster 4: [48, 8, 27, 23, 6, 7, 1, 26, 32, 31, 28], con demanda final: 156
#          - Nodos totales: 50
# • INICIANDO ACO(BWACS):
# [0.00012046491438470069, 0.0001278472732709808, 0.000211546303599152, 0.00010880283273445991, 0.0001621931923780779]
# [0.001204649143847007, 0.0012784727327098079, 0.00211546303599152, 0.0010880283273445991, 0.001621931923780779]
#
#     • CLUSTER 1
#         > Iteración 1
# 0
#             - Mejor costo para cluster 1: 11938.40670707206
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 1
#         > Iteración 7
# 2
#         > Iteración 8
# 6
#         > Iteración 9
# 9
#         > Iteración 10
# 9
#             - Mejor costo para cluster 1: 11421.440168312483
#         > Iteración 11
# 7
#         > Iteración 12
# 7
#             - Mejor costo para cluster 1: 10092.815784619028
#         > Iteración 13
# 7
#         > Iteración 14
# 9
#         > Iteración 15
# 8
#         > Iteración 16
# 8
#         > Iteración 17
# 8
#         > Iteración 18
# 9
#         > Iteración 19
# 10
#         > Iteración 20
# 10
#         > Iteración 21
# 10
#         > Iteración 22
# 9
#         > Iteración 23
# 10
#         > Iteración 24
# 9
#         > Iteración 25
# 9
#         > Iteración 26
# 9
#         > Iteración 27
# 9
#         > Iteración 28
# 0
#         > Iteración 29
# 0
#         > Iteración 30
# 0
#         > Iteración 31
# 0
#         > Iteración 32
# 1
#         > Iteración 33
# 1
#         > Iteración 34
# 3
#         > Iteración 35
# 5
#         > Iteración 36
# 9
#         > Iteración 37
# 9
#         > Iteración 38
# 9
#         > Iteración 39
# 9
#         > Iteración 40
# 9
#         > Iteración 41
# 9
#         > Iteración 42
# 9
#         > Iteración 43
# 0
#         > Iteración 44
# 0
#         > Iteración 45
# 0
#         > Iteración 46
# 0
#         > Iteración 47
# 0
#         > Iteración 48
# 0
#         > Iteración 49
# 4
#         > Iteración 50
# 7
#
#     • CLUSTER 2
#         > Iteración 1
# 0
#             - Mejor costo para cluster 2: 20600.20103232687
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#             - Mejor costo para cluster 2: 15562.137268381046
#         > Iteración 7
# 0
#             - Mejor costo para cluster 2: 14668.936616768318
#         > Iteración 8
# 0
#         > Iteración 9
# 0
#         > Iteración 10
# 2
#             - Mejor costo para cluster 2: 13803.226715912479
#         > Iteración 11
# 2
#         > Iteración 12
# 3
#         > Iteración 13
# 4
#         > Iteración 14
# 4
#         > Iteración 15
# 4
#         > Iteración 16
# 4
#             - Mejor costo para cluster 2: 13131.319133608036
#         > Iteración 17
# 2
#             - Mejor costo para cluster 2: 11844.865544845492
#         > Iteración 18
# 5
#         > Iteración 19
# 5
#         > Iteración 20
# 6
#         > Iteración 21
# 6
#         > Iteración 22
# 7
#         > Iteración 23
# 8
#         > Iteración 24
# 8
#         > Iteración 25
# 8
#         > Iteración 26
# 9
#         > Iteración 27
# 9
#         > Iteración 28
# 9
#         > Iteración 29
# 9
#         > Iteración 30
# 9
#         > Iteración 31
# 9
#         > Iteración 32
# 9
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 0
#         > Iteración 39
# 1
#         > Iteración 40
# 4
#         > Iteración 41
# 6
#         > Iteración 42
# 8
#         > Iteración 43
# 9
#         > Iteración 44
# 9
#         > Iteración 45
# 9
#         > Iteración 46
# 9
#         > Iteración 47
# 9
#         > Iteración 48
# 0
#         > Iteración 49
# 0
#         > Iteración 50
# 0
#
#     • CLUSTER 3
#         > Iteración 1
# 0
#             - Mejor costo para cluster 3: 10495.142709188822
#         > Iteración 2
# 0
#             - Mejor costo para cluster 3: 7053.948445829916
#         > Iteración 3
# 0
#             - Mejor costo para cluster 3: 5891.752492560112
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 3
#         > Iteración 7
# 3
#         > Iteración 8
# 3
#         > Iteración 9
# 3
#         > Iteración 10
# 6
#         > Iteración 11
# 6
#         > Iteración 12
# 6
#         > Iteración 13
# 6
#         > Iteración 14
# 6
#         > Iteración 15
# 6
#         > Iteración 16
# 6
#         > Iteración 17
# 6
#         > Iteración 18
# 6
#         > Iteración 19
# 0
#         > Iteración 20
# 0
#         > Iteración 21
# 0
#         > Iteración 22
# 0
#         > Iteración 23
# 0
#         > Iteración 24
# 0
#         > Iteración 25
# 0
#         > Iteración 26
# 4
#         > Iteración 27
# 6
#         > Iteración 28
# 6
#         > Iteración 29
# 6
#         > Iteración 30
# 6
#         > Iteración 31
# 6
#         > Iteración 32
# 6
#         > Iteración 33
# 6
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 0
#         > Iteración 39
# 0
#         > Iteración 40
# 2
#         > Iteración 41
# 3
#         > Iteración 42
# 6
#         > Iteración 43
# 6
#         > Iteración 44
# 6
#         > Iteración 45
# 6
#         > Iteración 46
# 6
#             - Mejor costo para cluster 3: 5809.339997924701
#         > Iteración 47
# 3
#         > Iteración 48
# 3
#         > Iteración 49
# 6
#         > Iteración 50
# 4
#
#     • CLUSTER 4
#         > Iteración 1
# 0
#             - Mejor costo para cluster 4: 17506.41480035904
#         > Iteración 2
# 0
#             - Mejor costo para cluster 4: 16296.984376516488
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#             - Mejor costo para cluster 4: 15416.925494729925
#         > Iteración 7
# 2
#         > Iteración 8
# 2
#         > Iteración 9
# 2
#         > Iteración 10
# 3
#         > Iteración 11
# 3
#         > Iteración 12
# 4
#         > Iteración 13
# 4
#         > Iteración 14
# 5
#         > Iteración 15
# 6
#         > Iteración 16
# 9
#         > Iteración 17
# 11
#         > Iteración 18
# 11
#         > Iteración 19
# 11
#             - Mejor costo para cluster 4: 15153.51249942041
#         > Iteración 20
# 8
#         > Iteración 21
# 8
#         > Iteración 22
# 8
#         > Iteración 23
# 8
#         > Iteración 24
# 9
#         > Iteración 25
# 11
#         > Iteración 26
# 10
#         > Iteración 27
# 10
#         > Iteración 28
# 10
#         > Iteración 29
# 11
#         > Iteración 30
# 11
#         > Iteración 31
# 10
#         > Iteración 32
# 11
#         > Iteración 33
# 12
#         > Iteración 34
# 12
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 0
#         > Iteración 39
# 0
#         > Iteración 40
# 0
#         > Iteración 41
# 2
#         > Iteración 42
# 2
#         > Iteración 43
# 3
#         > Iteración 44
# 7
#         > Iteración 45
# 11
#         > Iteración 46
# 11
#         > Iteración 47
# 11
#         > Iteración 48
# 11
#         > Iteración 49
# 11
#         > Iteración 50
# 0
#
#     • CLUSTER 5
#         > Iteración 1
# 0
#             - Mejor costo para cluster 5: 11487.081280890978
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#         > Iteración 7
# 0
#         > Iteración 8
# 4
#         > Iteración 9
# 9
#         > Iteración 10
# 9
#         > Iteración 11
# 9
#         > Iteración 12
# 10
#         > Iteración 13
# 10
#             - Mejor costo para cluster 5: 10704.725118997114
#         > Iteración 14
# 6
#         > Iteración 15
# 6
#         > Iteración 16
# 6
#         > Iteración 17
# 6
#         > Iteración 18
# 6
#         > Iteración 19
# 6
#         > Iteración 20
# 6
#         > Iteración 21
# 7
#         > Iteración 22
# 8
#         > Iteración 23
# 10
#         > Iteración 24
# 11
#         > Iteración 25
# 11
#         > Iteración 26
# 11
#         > Iteración 27
# 10
#         > Iteración 28
# 10
#         > Iteración 29
# 0
#         > Iteración 30
# 0
#         > Iteración 31
# 0
#         > Iteración 32
# 0
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#             - Mejor costo para cluster 5: 10106.639991832935
#         > Iteración 36
# 2
#         > Iteración 37
# 4
#         > Iteración 38
# 9
#         > Iteración 39
# 9
#         > Iteración 40
# 9
#         > Iteración 41
# 9
#         > Iteración 42
# 10
#         > Iteración 43
# 10
#         > Iteración 44
# 10
#         > Iteración 45
# 10
#         > Iteración 46
# 10
#         > Iteración 47
# 10
#         > Iteración 48
# 10
#         > Iteración 49
# 10
#         > Iteración 50
# 10
#
# ...
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10224.697698766111
#
#     > ITERACIÓN 34
#         - Centroides actuales: [array([53.09090909, 54.63636364]), array([48.63636364, 34.63636364]), array([12.71428571, 25.28571429]), array([29.09090909, 22.27272727]), array([22.4, 54.6])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8205.405893565472
#
#     > ITERACIÓN 35
#         - Centroides actuales: [array([51.18181818, 57.45454545]), array([59., 15.]), array([12.        , 27.71428571]), array([29.2, 17.6]), array([22.63636364, 55.18181818])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9840.425181254781
#
#     > ITERACIÓN 36
#         - Centroides actuales: [array([51.6, 56.2]), array([53. , 31.5]), array([12.71428571, 25.28571429]), array([32.33333333, 23.83333333]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9209.872196275994
#
#     > ITERACIÓN 37
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([53.27272727, 32.09090909]), array([12.        , 27.71428571]), array([46., 10.]), array([18.5, 52.2])]
#         - Nodos sin asignar: [18 39], [9 7]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8682.729335656946
#
#     > ITERACIÓN 38
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([5., 6.]), array([38.5, 18.1]), array([19.2, 55.8])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9938.838033288544
#
#     > ITERACIÓN 39
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([12.25, 21.  ]), array([59., 15.]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24 42], [28 11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8844.914022470824
#
#     > ITERACIÓN 40
#         - Centroides actuales: [array([48.36363636, 57.72727273]), array([46.6, 36.5]), array([ 7., 38.]), array([45.77777778, 18.77777778]), array([ 5., 64.])]
#         - Nodos sin asignar: [40], [27]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10771.024281503887
#
#     > ITERACIÓN 41
#         - Centroides actuales: [array([48.18181818, 52.27272727]), array([46.33333333, 36.44444444]), array([10., 17.]), array([42. , 17.4]), array([20.4, 53.5])]
#         - Nodos sin asignar: [30], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9760.871029384165
#
#     > ITERACIÓN 42
#         - Centroides actuales: [array([37., 69.]), array([48.6, 34.4]), array([19.88888889, 25.66666667]), array([35.8, 20.2]), array([19.2, 55.8])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9867.190655216931
#
#     > Mejor Clusterización: [array([ 2, 16, 29, 11, 22, 32, 20,  1,  3, 35], dtype=int64), array([ 9, 49, 30, 50, 10, 38, 34, 21, 39, 33, 45], dtype=int64), array([18, 13,  4, 41, 25, 14, 19], dtype=int64), array([17, 37, 12, 47, 44,  5, 15, 46, 42, 40], dtype=int64), array([48,  7, 23,  8, 26,  6, 27, 31, 24, 43], dtype=int64)], con costo final: 8066.528567941032, nodos sin asignar: [28 36]
#     > Mejor Clusterización (Contraint): [array([ 2, 29, 20, 16, 21, 22,  3, 11, 35, 36], dtype=int64), array([49,  9, 38,  5, 10, 30, 50, 34, 39, 43], dtype=int64), array([18, 47, 12, 14, 46, 25, 24], dtype=int64), array([ 4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], dtype=int64), array([48,  8, 27, 23,  6,  7,  1, 26, 32, 31, 28], dtype=int64)], con costo final: 9326.960082949558, nodos sin asignar: []
#     --- 0.21500015258789062 seconds ---
#
#     > CLUSTERS
#          - Cluster 0: [2, 29, 20, 16, 21, 22, 3, 11, 35, 36], con demanda final: 153
#          - Cluster 1: [49, 9, 38, 5, 10, 30, 50, 34, 39, 43], con demanda final: 150
#          - Cluster 2: [18, 47, 12, 14, 46, 25, 24], con demanda final: 159
#          - Cluster 3: [4, 17, 37, 44, 42, 41, 19, 15, 13, 45, 40, 33], con demanda final: 159
#          - Cluster 4: [48, 8, 27, 23, 6, 7, 1, 26, 32, 31, 28], con demanda final: 156
#          - Nodos totales: 50
# • INICIANDO ACO(BWACS):
# [0.00012046491438470069, 0.0001278472732709808, 0.000211546303599152, 0.00010880283273445991, 0.0001621931923780779]
# [0.001204649143847007, 0.0012784727327098079, 0.00211546303599152, 0.0010880283273445991, 0.001621931923780779]
#
#     • CLUSTER 1
#         > Iteración 1
# 0
#             - Mejor costo para cluster 1: 11152.314252457592
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 4
#         > Iteración 7
# 7
#         > Iteración 8
# 8
#         > Iteración 9
# 9
#         > Iteración 10
# 9
#         > Iteración 11
# 9
#         > Iteración 12
# 9
#         > Iteración 13
# 9
#         > Iteración 14
# 9
#         > Iteración 15
# 9
#         > Iteración 16
# 9
#         > Iteración 17
# 0
#         > Iteración 18
# 0
#         > Iteración 19
# 0
#         > Iteración 20
# 0
#         > Iteración 21
# 0
#         > Iteración 22
# 1
#         > Iteración 23
# 7
#         > Iteración 24
# 8
#         > Iteración 25
# 9
#         > Iteración 26
# 9
#         > Iteración 27
# 9
#         > Iteración 28
# 9
#         > Iteración 29
# 9
#         > Iteración 30
# 9
#         > Iteración 31
# 9
#         > Iteración 32
# 0
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 2
#         > Iteración 39
# 7
#         > Iteración 40
# 8
#         > Iteración 41
# 9
#         > Iteración 42
# 9
#         > Iteración 43
# 9
#             - Mejor costo para cluster 1: 10748.445624951382
#         > Iteración 44
# 4
#         > Iteración 45
# 6
#         > Iteración 46
# 6
#         > Iteración 47
# 7
#         > Iteración 48
# 10
#         > Iteración 49
# 11
#         > Iteración 50
# 10
#
#     • CLUSTER 2
#         > Iteración 1
# 0
#             - Mejor costo para cluster 2: 14193.830479458833
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#         > Iteración 7
# 0
#         > Iteración 8
# 1
#         > Iteración 9
# 3
#         > Iteración 10
# 8
#         > Iteración 11
# 9
#         > Iteración 12
# 9
#         > Iteración 13
# 9
#         > Iteración 14
# 9
#         > Iteración 15
# 9
#         > Iteración 16
# 9
#         > Iteración 17
# 0
#         > Iteración 18
# 0
#         > Iteración 19
# 0
#         > Iteración 20
# 0
#         > Iteración 21
# 0
#         > Iteración 22
# 0
#         > Iteración 23
# 0
#         > Iteración 24
# 1
#         > Iteración 25
# 2
#         > Iteración 26
# 6
#         > Iteración 27
# 8
#         > Iteración 28
# 8
#         > Iteración 29
# 8
#         > Iteración 30
# 9
#         > Iteración 31
# 9
#         > Iteración 32
# 0
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#             - Mejor costo para cluster 2: 13606.047106475846
#         > Iteración 38
# 0
#         > Iteración 39
# 2
#         > Iteración 40
# 4
#         > Iteración 41
# 4
#         > Iteración 42
# 4
#         > Iteración 43
# 4
#         > Iteración 44
# 4
#         > Iteración 45
# 4
#         > Iteración 46
# 4
#         > Iteración 47
# 4
#         > Iteración 48
# 7
#         > Iteración 49
# 9
#         > Iteración 50
# 9
#
#     • CLUSTER 3
#         > Iteración 1
# 0
#             - Mejor costo para cluster 3: 11632.113591547306
#         > Iteración 2
# 0
#             - Mejor costo para cluster 3: 9215.717294448936
#         > Iteración 3
# 0
#             - Mejor costo para cluster 3: 6979.825091096387
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#         > Iteración 7
# 1
#         > Iteración 8
# 1
#             - Mejor costo para cluster 3: 5809.339997924701
#         > Iteración 9
# 3
#         > Iteración 10
# 3
#         > Iteración 11
# 4
#         > Iteración 12
# 4
#         > Iteración 13
# 6
#         > Iteración 14
# 6
#         > Iteración 15
# 6
#         > Iteración 16
# 6
#         > Iteración 17
# 6
#         > Iteración 18
# 6
#         > Iteración 19
# 6
#         > Iteración 20
# 6
#         > Iteración 21
# 6
#         > Iteración 22
# 6
#         > Iteración 23
# 8
#         > Iteración 24
# 0
#         > Iteración 25
# 0
#         > Iteración 26
# 0
#         > Iteración 27
# 0
#         > Iteración 28
# 0
#         > Iteración 29
# 6
#         > Iteración 30
# 6
#         > Iteración 31
# 6
#         > Iteración 32
# 6
#         > Iteración 33
# 6
#         > Iteración 34
# 6
#         > Iteración 35
# 6
#         > Iteración 36
# 6
#         > Iteración 37
# 6
#         > Iteración 38
# 6
#         > Iteración 39
# 0
#         > Iteración 40
# 0
#         > Iteración 41
# 0
#         > Iteración 42
# 0
#         > Iteración 43
# 0
#         > Iteración 44
# 2
#         > Iteración 45
# 6
#         > Iteración 46
# 6
#         > Iteración 47
# 6
#         > Iteración 48
# 6
#         > Iteración 49
# 6
#         > Iteración 50
# 6
#
#     • CLUSTER 4
#         > Iteración 1
# 0
#             - Mejor costo para cluster 4: 18012.131585326475
#         > Iteración 2
# 0
#             - Mejor costo para cluster 4: 15288.632924229403
#         > Iteración 3
# 0
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#         > Iteración 7
# 5
#         > Iteración 8
# 6
#         > Iteración 9
# 9
#         > Iteración 10
# 10
#         > Iteración 11
# 10
#         > Iteración 12
# 11
#         > Iteración 13
# 11
#         > Iteración 14
# 11
#         > Iteración 15
# 11
#         > Iteración 16
# 11
#         > Iteración 17
# 11
#         > Iteración 18
# 0
#         > Iteración 19
# 0
#         > Iteración 20
# 0
#         > Iteración 21
# 0
#         > Iteración 22
# 0
#         > Iteración 23
# 0
#         > Iteración 24
# 0
#         > Iteración 25
# 3
#         > Iteración 26
# 3
#         > Iteración 27
# 10
#         > Iteración 28
# 11
#         > Iteración 29
# 11
#         > Iteración 30
# 11
#         > Iteración 31
# 11
#         > Iteración 32
# 11
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#         > Iteración 37
# 0
#         > Iteración 38
# 0
#         > Iteración 39
# 0
#         > Iteración 40
# 2
#         > Iteración 41
# 7
#         > Iteración 42
# 9
#         > Iteración 43
# 9
#         > Iteración 44
# 10
#         > Iteración 45
# 11
#         > Iteración 46
# 11
#         > Iteración 47
# 11
#         > Iteración 48
# 0
#         > Iteración 49
# 0
#         > Iteración 50
# 0
#
#     • CLUSTER 5
#         > Iteración 1
# 0
#             - Mejor costo para cluster 5: 12665.48492829186
#         > Iteración 2
# 0
#         > Iteración 3
# 0
#             - Mejor costo para cluster 5: 11487.081280890978
#         > Iteración 4
# 0
#         > Iteración 5
# 0
#         > Iteración 6
# 0
#         > Iteración 7
# 2
#         > Iteración 8
# 4
#         > Iteración 9
# 4
#         > Iteración 10
# 8
#         > Iteración 11
# 8
#         > Iteración 12
# 10
#         > Iteración 13
# 10
#         > Iteración 14
# 10
#         > Iteración 15
# 10
#         > Iteración 16
# 10
#             - Mejor costo para cluster 5: 10824.09825833819
#         > Iteración 17
# 9
#         > Iteración 18
# 9
#         > Iteración 19
# 10
#         > Iteración 20
# 9
#         > Iteración 21
# 9
#         > Iteración 22
# 10
#         > Iteración 23
# 10
#         > Iteración 24
# 9
#         > Iteración 25
# 9
#         > Iteración 26
# 10
#         > Iteración 27
# 10
#         > Iteración 28
# 10
#         > Iteración 29
# 10
#         > Iteración 30
# 10
#         > Iteración 31
# 10
#         > Iteración 32
# 0
#         > Iteración 33
# 0
#         > Iteración 34
# 0
#         > Iteración 35
# 0
#         > Iteración 36
# 0
#             - Mejor costo para cluster 5: 10704.725118997114
#         > Iteración 37
# 0
#         > Iteración 38
# 0
#         > Iteración 39
# 0
#         > Iteración 40
# 5
#         > Iteración 41
# 5
#         > Iteración 42
# 5
#         > Iteración 43
# 6
#         > Iteración 44
# 10
#         > Iteración 45
# 10
#         > Iteración 46
# 10
#         > Iteración 47
# 10
#         > Iteración 48
# 10
#         > Iteración 49
# 10
#         > Iteración 50
# 10
#
#  RUTAS OBTENIDAS POR LA COLONIA
# > RUTA 0: [0, 0, 16, 21, 29, 36, 35, 20, 3, 22, 2, 11, 0], con demanda final: 153
# > RUTA 1: [0, 43, 50, 34, 30, 10, 39, 49, 38, 9, 5, 0], con demanda final: 150
# > RUTA 2: [0, 24, 14, 25, 18, 47, 12, 46, 0], con demanda final: 159
# > RUTA 3: [0, 0, 4, 13, 41, 19, 40, 42, 45, 33, 15, 44, 37, 17, 0], con demanda final: 159
# > RUTA 4: [0, 27, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 0], con demanda final: 156
# > Energia total final: 56157.19077257845
# > Distancia total final: inf
#
# --- 0.3489992618560791 seconds ---
# Solutions for instance CMT1: [(54628.45138458557, [[0, 21, 29, 20, 35, 36, 3, 22, 2, 16, 11, 0], [0, 43, 49, 9, 50, 34, 30, 39, 10, 5, 38, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 17, 37, 15, 45, 33, 44, 42, 40, 19, 41, 13, 4, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0]], inf, 0.3549995422363281), (53007.173818642565, [[0, 0, 22, 3, 36, 35, 20, 29, 21, 16, 2, 11, 0], [0, 43, 9, 50, 34, 30, 39, 10, 49, 38, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 0, 4, 13, 40, 41, 19, 42, 44, 15, 45, 33, 37, 17, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0]], inf, 0.34799981117248535), (56707.08519130001, [[0, 0, 16, 29, 21, 20, 35, 36, 3, 22, 2, 11, 0], [0, 43, 39, 49, 9, 50, 34, 30, 10, 5, 38, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 40, 4, 17, 37, 44, 15, 45, 33, 42, 19, 41, 13, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 27, 6, 0]], inf, 0.33899879455566406), (54091.99920028067, [[0, 22, 3, 20, 35, 36, 29, 21, 16, 2, 11, 0], [0, 43, 38, 49, 10, 39, 30, 34, 50, 9, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 17, 37, 15, 45, 33, 44, 42, 40, 19, 41, 13, 4, 0], [0, 1, 32, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0]], inf, 0.34400153160095215), (56030.71744639316, [[0, 21, 29, 20, 35, 36, 3, 22, 2, 16, 11, 0], [0, 43, 5, 38, 9, 50, 34, 30, 39, 10, 49, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 0, 4, 17, 37, 15, 45, 33, 44, 42, 40, 19, 41, 13, 0], [0, 0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 27, 6, 0]], inf, 0.3430001735687256), (54487.59211689503, [[0, 16, 29, 21, 20, 35, 36, 3, 22, 2, 11, 0], [0, 43, 10, 39, 30, 34, 50, 9, 49, 38, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 0, 13, 41, 40, 19, 42, 44, 15, 45, 33, 37, 17, 4, 0], [0, 27, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 0]], inf, 0.3429994583129883), (54886.44952417664, [[0, 21, 29, 20, 35, 36, 3, 22, 2, 16, 11, 0], [0, 43, 10, 39, 49, 9, 50, 34, 30, 38, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 17, 37, 15, 45, 33, 44, 42, 40, 19, 41, 13, 4, 0], [0, 28, 31, 26, 8, 48, 7, 23, 6, 27, 1, 32, 0]], inf, 0.34200000762939453), (53687.701841593, [[0, 21, 29, 20, 35, 36, 3, 22, 2, 16, 11, 0], [0, 43, 39, 10, 49, 9, 50, 34, 30, 38, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 17, 37, 15, 45, 33, 44, 42, 19, 40, 41, 13, 4, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0]], inf, 0.3510000705718994), (54057.352476988366, [[0, 21, 29, 20, 35, 36, 3, 22, 2, 16, 11, 0], [0, 43, 38, 49, 10, 39, 30, 34, 50, 9, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 17, 4, 13, 41, 19, 40, 42, 44, 15, 45, 33, 37, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0]], inf, 0.34200000762939453), (56157.19077257845, [[0, 0, 16, 21, 29, 36, 35, 20, 3, 22, 2, 11, 0], [0, 43, 50, 34, 30, 10, 39, 49, 38, 9, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 0, 4, 13, 41, 19, 40, 42, 45, 33, 15, 44, 37, 17, 0], [0, 27, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 0]], inf, 0.3489992618560791)]
# 10 runs for instance CMT1 finished at 20230320_000317
# Best solution for instance CMT1: (53007.173818642565, [[0, 0, 22, 3, 36, 35, 20, 29, 21, 16, 2, 11, 0], [0, 43, 9, 50, 34, 30, 39, 10, 49, 38, 5, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 0, 4, 13, 40, 41, 19, 42, 44, 15, 45, 33, 37, 17, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 6, 27, 0]], inf, 0.34799981117248535)
# Worst solution for instance CMT1: (56707.08519130001, [[0, 0, 16, 29, 21, 20, 35, 36, 3, 22, 2, 11, 0], [0, 43, 39, 49, 9, 50, 34, 30, 10, 5, 38, 0], [0, 24, 14, 25, 18, 47, 12, 46, 0], [0, 40, 4, 17, 37, 44, 15, 45, 33, 42, 19, 41, 13, 0], [0, 32, 1, 28, 31, 8, 26, 7, 23, 48, 27, 6, 0]], inf, 0.33899879455566406)
