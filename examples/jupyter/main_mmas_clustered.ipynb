# %%
# Third-party imports
from math import ceil
import numpy as np
import os
import vrplib

# Own imports
from src.new.acs import MMAS
from src.new.ants import FreeAnt
from src.new.display import DisplayModel
from src.new.helpers import create_directory, download_instance, get_distances_matrix
from src.new.heuristics import HeuristicModel
from src.new.machine_learning import KMeans
from src.new.metaheuristics import GeneralVNS
from src.new.models import VRPModel

# %%
# Parameters to handle the algorithm
# %matplotlib inline

ALPHA = 1  # 0.75, 1, 1.05, 1.1, 1.25, 1.5, 1.75, 2
ANTS_NUM_RELATION = 2  # 1, 2
BETA = 2  # 2, 2.5, 3,  3.5
CANDIDATE_NODES_TYPE = None # None, 'best', 'random'
DELTA = 0.1 # 0.1, 0.1, 0.5, 1.0
GAMMA = 0
HEURISTICS_TO_USE = ['distance'] # ['distance'], ['distance', 'saving'], ['distance', 'capacity'],  ['distance', 'saving', 'capacity']
INITIAL_PHEROMONES_TYPE = 'tau_max' # 'tau_max', 'tau_zero'
ALL_SOLUTIONS_LOCAL_SEARCH_MODEL = None  # None, GeneralVNS
ITERATION_LOCAL_SEARCH_MODEL = None  # None, GeneralVNS
LAMBDA = 10
MAX_ITERATIONS = 1000
MIN_ITERATIONS = 1000
PERCENT_ITERATIONS_RESTART = 0.15 # 0.1, 0.15, 0.2, 0.25, 0.3
PHEROMONES_ONLINE_UPDATE = False  # True, False
PHEROMONES_UPDATE_TYPE = 'pseudo_g_best' # 'all_ants', 'it_best', 'g_best', 'pseudo_g_best'
PROBABILITIES_MATRIX_TYPE = 'classic'  # 'classic', 'normalized'
Q_0 = 0.6  # 0.8, 0.85, 0.9, 0.95
RHO = 0.9  # 0.05, 0.1, 0.15, 0.2, 0.25, 0.3
SIMILARITY_OF_ARCS_STAGNATION = None # None, 0.5, 0.6, 0.7, 0.75, 0.8
SIMILARITY_OF_QUALITIES_STAGNATION = None # None, 0.885, 0.89, 0.9, 0.92, 0.95, 0.99
TARE_PERCENTAGE = 0.15

# Instance to solve
LIB = 'CMT'
INSTANCE = 'CMT5'

# Parameters to handle the display
PLOT_INSTANCE = False
PLOT_CLUSTERS = True
PLOT_SOLUTION = True
PLOT_MOST_USED_ARCS = False
PLOT_PHEROMONES_MATRIX = True

# %%
# Initialize everything
project_path = os.getcwd()
instance_file_exists = os.path.isfile(
    f'{project_path}/instances/CVRPLIB/{LIB}/{INSTANCE}.vrp')

if not instance_file_exists:
    create_directory(f'{project_path}/instances/CVRPLIB/{LIB}/{INSTANCE}/')
    success = download_instance(
        INSTANCE, f'{project_path}/instances/CVRPLIB/{LIB}/')

    if not success:
        raise Exception('Error downloading the instance')


instance = vrplib.read_instance(
    f'{project_path}/instances/CVRPLIB/{LIB}/{INSTANCE}.vrp')
solution = vrplib.read_solution(
    f'{project_path}/instances/CVRPLIB/{LIB}/{INSTANCE}.sol')

demands = instance['demand']
nodes = [node for node in range(len(demands))]
clients = nodes[1:]
max_capacity = instance['capacity']
matrix_coords = instance['node_coord']
k_optimal = ceil(sum(demands)/max_capacity)

optimal_cost = None
if solution['cost']:
    optimal_cost = solution['cost']
else:
    optimal_cost = float(instance['comment']) if instance['comment'] else None

errors = VRPModel.validate_instance(nodes, demands, max_capacity)
if errors:
    raise Exception(errors)

iterations = max(round(len(nodes), -2), MIN_ITERATIONS)
matrix_distances = get_distances_matrix(nodes, matrix_coords)

parameters_heuristics = {
    'demands': demands,
    'importance_capacity': LAMBDA,
    'importance_distances': BETA,
    'importance_savings': GAMMA,
    'matrix_coords': matrix_coords,
    'max_capacity': max_capacity,
    'nodes': nodes[:],
}

heuristics = HeuristicModel(**parameters_heuristics)
matrix_heuristics = heuristics.get_heuristic_matrix(HEURISTICS_TO_USE)

parameters_kmeans = {
    'demands': np.array(demands),
    'k_optimal': k_optimal,
    'matrix_coords': matrix_coords[:],
    'matrix_distances': matrix_distances[:],
    'max_capacity': max_capacity,
    'nodes': nodes[:],
}

kmeans = KMeans(**parameters_kmeans)
best_constraint_clusters, clusters_arcs, best_cost, centroids, _, lst_clusters = kmeans.run()
clusters_reversed = lst_clusters[::-1]
best_clusters = clusters_reversed[:2]
best_clusters = best_clusters.append(best_constraint_clusters)

parameters_ants = {
    'alpha': ALPHA,
    'ants_num': ceil(len(clients) / ANTS_NUM_RELATION),
    'delta': DELTA,
    'demands': demands,
    'ipynb': True,
    'k_optimal': k_optimal,
    'lst_clusters': [best_constraint_clusters],
    # 'lst_clusters': best_clusters,
    'matrix_coords': matrix_coords,
    'matrix_costs': matrix_distances,
    'matrix_heuristics': matrix_heuristics,
    'max_capacity': max_capacity,
    'max_iterations': min(iterations, MAX_ITERATIONS),
    'model_ant': FreeAnt,
    'model_ls_it': ITERATION_LOCAL_SEARCH_MODEL,
    'model_problem': VRPModel,
    'nodes': nodes,
    'percent_arcs_limit': SIMILARITY_OF_ARCS_STAGNATION,
    'percent_iterations_restart':PERCENT_ITERATIONS_RESTART,
    'percent_quality_limit': SIMILARITY_OF_QUALITIES_STAGNATION,
    'pheromones_online_update': PHEROMONES_ONLINE_UPDATE,
    'q0': Q_0,
    'rho': RHO,
    'tare': max_capacity * TARE_PERCENTAGE,
    'type_initial_pheromone': INITIAL_PHEROMONES_TYPE,
    'type_candidate_nodes': CANDIDATE_NODES_TYPE,
    'type_pheromones_update': PHEROMONES_UPDATE_TYPE,
    'type_probabilities_matrix': PROBABILITIES_MATRIX_TYPE,
}
# Out:
#     > Iteration: 1/160
#         - Unassigned nodes: [104 158], [3 3]
#         - Best previous total cost: inf
#         - New total cost: 3961.6198065657063
#
#     > Iteration: 2/160
#         - Unassigned nodes: [136], [16]
#         - Best previous total cost: 3961.6198065657063
#         - New total cost: 2006.9607493820936
#
#     > Iteration: 3/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 2006.9607493820936
#         - New total cost: 1898.3379981996193
#
#     > Iteration: 4/160
#         - Unassigned nodes: [ 69 134], [8 5]
#         - Best previous total cost: 1898.3379981996193
#         - New total cost: 1694.1317063293636
#
#     > Iteration: 5/160
#         - Unassigned nodes: [83 84], [17  6]
#         - Best previous total cost: 1694.1317063293636
#         - New total cost: 1752.9427880863216
#
#     > Iteration: 6/160
#         - Unassigned nodes: [162], [9]
#         - Best previous total cost: 1694.1317063293636
#         - New total cost: 1629.165650644143
#
#     > Iteration: 7/160
#         - Unassigned nodes: [ 69 123], [8 6]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1639.4744137514656
#
#     > Iteration: 8/160
#         - Unassigned nodes: [139  58], [5 5]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1675.3998005025933
#
#     > Iteration: 9/160
#         - Unassigned nodes: [122], [3]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1648.3201447093943
#
#     > Iteration: 10/160
#         - Unassigned nodes: [162  84], [9 6]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1661.8244203230206
#
#     > Iteration: 11/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1739.3240224679207
#
#     > Iteration: 12/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1692.0938791331105
#
#     > Iteration: 13/160
#         - Unassigned nodes: [162], [9]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1651.7361470899073
#
#     > Iteration: 14/160
#         - Unassigned nodes: [134], [5]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1743.3171393698688
#
#     > Iteration: 15/160
#         - Unassigned nodes: [ 84 115], [6 2]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1743.6515325256792
#
#     > Iteration: 16/160
#         - Unassigned nodes: [162  74], [9 7]
#         - Best previous total cost: 1629.165650644143
#         - New total cost: 1584.8938431328095
#
#     > Iteration: 17/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1767.6031288317831
#
#     > Iteration: 18/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1733.3420369544222
#
#     > Iteration: 19/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1691.5540692240181
#
#     > Iteration: 20/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1659.7182339076082
#
#     > Iteration: 21/160
#         - Unassigned nodes: [162  88], [9 7]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1642.5755582182646
#
#     > Iteration: 22/160
#         - Unassigned nodes: [123], [6]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1766.9278367156141
#
#     > Iteration: 23/160
#         - Unassigned nodes: [84], [6]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1703.8946124315514
#
#     > Iteration: 24/160
#         - Unassigned nodes: [162], [9]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1668.4879594764047
#
#     > Iteration: 25/160
#         - Unassigned nodes: [141], [7]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1674.8378531192927
#
#     > Iteration: 26/160
#         - Unassigned nodes: [ 74 122], [7 3]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1683.9073709021613
#
#     > Iteration: 27/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1851.3611680226888
#
#     > Iteration: 28/160
#         - Unassigned nodes: [162  88  84], [9 7 6]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1587.0938833914554
#
#     > Iteration: 29/160
#         - Unassigned nodes: [134], [5]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1716.3500009684683
#
#     > Iteration: 30/160
#         - Unassigned nodes: [163], [20]
#         - Best previous total cost: 1584.8938431328095
#         - New total cost: 1566.6340923745288
#
#     > Iteration: 31/160
#         - Unassigned nodes: [133], [8]
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1684.9347122583195
#
#     > Iteration: 32/160
#         - Unassigned nodes: [ 14 115], [8 2]
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1583.6028687832231
#
#     > Iteration: 33/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1898.8057705571507
#
#     > Iteration: 34/160
#         - Unassigned nodes: [88], [7]
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1751.696121345025
#
#     > Iteration: 35/160
#         - Unassigned nodes: [134], [5]
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1703.2172729855622
#
#     > Iteration: 36/160
#         - Unassigned nodes: [163], [20]
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1695.551566139624
#
#     > Iteration: 37/160
#         - Unassigned nodes: [162], [9]
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1588.9820802773263
#
#     > Iteration: 38/160
#         - Unassigned nodes: [], []
#         - Best previous total cost: 1566.6340923745288
#         - New total cost: 1660.6416508127986
#
#     > Best clusters:  [array([ 12,  26, 100, 130,  81,  50,  17,  60, 168, 149,  31, 169,  80,
#        119], dtype=int64), array([184,  43, 192,  90, 197, 115,  41, 160, 136, 137, 156, 116],
#       dtype=int64), array([ 88, 138,  37,   5, 122,  20, 103,  36, 166, 155, 124], dtype=int64), array([129,  10,  57, 131,   9,  38,  39, 109,  77,  71], dtype=int64), array([ 91, 113, 199, 186,  42, 185, 143,  22,  93,  68, 141, 142,  89],
#       dtype=int64), array([167,  27,  83,  99, 179, 153,  13,  79,  65,  29,  70,  15, 150],
#       dtype=int64), array([ 32, 187,  40,  97,  44, 161,  55,  76,   3, 151, 106, 162,  75],
#       dtype=int64), array([ 96,  33,  61, 193, 188,   6,  16, 126, 127, 105,  66], dtype=int64), array([ 63,  24, 107,  74, 144, 181, 104, 182, 117,  49,  25, 159, 163],
#       dtype=int64), array([171,  21,  47,  82, 173, 174, 121,  48, 172, 120,  94,  59, 140],
#       dtype=int64), array([ 35, 178, 180,  51, 132,   8,   7, 102,  19, 176,  78, 133, 177,
#        123], dtype=int64), array([  2, 157, 112,  54,  30,  28, 152, 139,  86,  64, 101, 114, 154],
#       dtype=int64), array([135, 146, 148, 147,  92,  18, 118,  56,  72,  73, 110, 189],
#       dtype=int64), array([158, 198,  53, 195,  67, 194,   1, 196,  62, 183,  23, 191,  95],
#       dtype=int64), array([ 11,  84,  69,  14, 170, 108,  52, 165, 134,  85, 145], dtype=int64), array([111,   4,  45,  46,  34,  87,  58, 125,  98, 175, 128, 190],
#       dtype=int64)] , with final cost: 1566.6340923745288, unassigned nodes: [164]
#     > Best clusters (Constraint):  [array([ 17,  40, 130, 126,  76,  81,  12,  26,  60, 168, 151,  50],
#       dtype=int64), array([143,  90, 185,  41, 115, 113,  68,  42, 137,  89, 142, 141,  95,
#        123], dtype=int64), array([138,  88,  47,   5, 122, 103,  37,  36, 174,  20, 145], dtype=int64), array([ 57, 131,  10,  39, 109, 129,  31,  80, 162, 189,  75, 119,  71],
#       dtype=int64), array([  1, 158, 184, 194, 196, 193, 136, 199, 197, 191,  91,  66],
#       dtype=int64), array([167,   8,  46, 102, 176,  65,  19, 175,  70,  13, 128, 164, 154],
#       dtype=int64), array([ 97,  32,   9, 161, 187,  44,  55, 181,   3, 106,  73, 107, 169,
#         85, 177], dtype=int64), array([ 54, 152,   4,  61,   2,   6, 127, 157, 125, 139, 190], dtype=int64), array([104, 182,  74,  16,  63,  24,  62, 144, 183, 117,  49, 159, 116],
#       dtype=int64), array([171, 172, 120,  21,  48,  30,  82, 121,  98, 173,  59, 155, 140],
#       dtype=int64), array([ 35, 178, 180,  51, 132,  14,   7,  78, 149, 133, 150, 100],
#       dtype=int64), array([ 28, 101,  64, 186,  93, 112,  86,  22, 156,  94, 166, 114,  15,
#        163], dtype=int64), array([118,  72, 147,  56, 146,  25, 148,  18, 110,  92, 135], dtype=int64), array([ 67, 198,  53, 192, 195,  33,  96,  43, 188, 160,  23, 105],
#       dtype=int64), array([ 52,  11,  38,  69, 165, 108, 170,  84,  77, 134], dtype=int64), array([ 27,  58, 111,  45,  83, 153,  34,  99,  79,  87,  29, 179, 124],
#       dtype=int64)] , with final cost: 1659.7182339076082, unassigned nodes: []
#     --- 0.8284330368041992 seconds ---

# %%
# Render the problem

if PLOT_INSTANCE:
    instance_name = INSTANCE.split('/')[-1]
    DisplayModel.render_problem(nodes, demands, matrix_coords, instance_name)

# %%
# Render the clusters
if PLOT_CLUSTERS:
    instance_name = INSTANCE.split('/')[-1]
    DisplayModel.render_k_means_clusters(
        best_constraint_clusters, centroids, matrix_coords, instance_name)

# %%
# Run the algorithm

# results_list = []

# for _ in range(10):
#     mmas = MMAS(**parameters_ants)
#     results = mmas.solve()
#     results_list.append(results)

mmas = MMAS(**parameters_ants)
results = mmas.solve()
# Out:
# PARAMETERS
# ----------------------------------------
# AS:
# 	alpha: 1
# 	ants_num: 100
# 	beta: 1
# 	demands: 200
# 	evaporation_rate: 0.9
# 	iterations_local_search: no
# 	k_optimal: 16
# 	lst_clusters: yes
# 	max_capacity: 200
# 	max_iterations: 1000
# 	min_demand: 1, max_demand: 41, mean: 15.93
# 	model_ant: Free Ant
# 	nodes: 199
# 	rho: 0.9
# 	t_max: 0.00472807054080867997236659050486196065321564674377
# 	t_min: 0.00000072073960969349609408584819703058599316136679
# 	t_zero: 0.00047280705408086793218452870135593002487439662218
# 	tare: 30.0
# 	type_candidate_nodes: None
# 	type_pheromones_update: pseudo_g_best
# 	type_probabilities_matrix: classic
# ----------------------------------------
# ACS:
# 	epsilon: 0.009000000000000001
# 	pheromones_local_update: no
# 	q0: 0.6
# ----------------------------------------
# MMAS:
# 	delta: 0.1
# 	initial_pheromones_value: 0.00472807054080868
# 	p_best: 0.05
# 	percent_arcs_limit: None
# 	percent_quality_limit: None
# 	type_initial_pheromone: tau_max
# Global Best -> 2017.73091:  10%|█         | 103/1000 [00:51<07:27,  2.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       1 # Run the algorithm
#       2
#       3 # results_list = []
#    (...)
#       7 #     results = mmas.solve()
#       8 #     results_list.append(results)
#      10 mmas = MMAS(**parameters_ants)
# ---> 11 results = mmas.solve()
#
# File e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\src\new\acs\mm_ant_system.py:351, in MMAS.solve(self)
#     347     ant_solution = ant.generate_solution(
#     348         candidate_nodes_weights[ant_idx]
#     349     )
#     350 else:
# --> 351     ant_solution = ant.generate_solution()
#     352 iterations_solutions.append(ant_solution)
#     354 # Update pheromones matrix with local update
#
# File e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\src\new\ants\free_ant.py:123, in FreeAnt.generate_solution(self, ant_best_start_nodes)
#     120 unvisited_nodes = self.clients.copy()
#     122 while unvisited_nodes:
# --> 123     route, route_arcs, route_cost, route_load = self.generate_route(
#     124         unvisited_nodes, ant_best_start_nodes
#     125     )
#     127     solution["routes"].append(route)
#     128     solution["routes_arcs"].append(route_arcs)
#
# File e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\src\new\ants\free_ant.py:92, in FreeAnt.generate_route(self, unvisited_nodes, ant_best_start_nodes)
#      89     route_arcs.append((self.depot, s))
#      91 while valid_nodes:
# ---> 92     s = self.choose_next_node(route[-1], valid_nodes)
#      94     route_cost += self.matrix_costs[route[-1]][s]
#      96     vehicle_load += self.lst_demands[s]
#
# File e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\src\new\ants\free_ant.py:55, in FreeAnt.choose_next_node(self, actual_node, valid_nodes)
#      52     return random.choices(valid_nodes, weights=prob_of_nodes, k=1)[0]
#      54 if random.random() <= self.q0:
# ---> 55     return valid_nodes[np.argmax(prob_of_nodes)]
#      56 else:
#      57     return random.choices(valid_nodes, weights=prob_of_nodes, k=1)[0]
#
# File <__array_function__ internals>:200, in argmax(*args, **kwargs)
#
# File e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\.conda\lib\site-packages\numpy\core\fromnumeric.py:1242, in argmax(a, axis, out, keepdims)
#    1155 """
#    1156 Returns the indices of the maximum values along an axis.
#    1157
#    (...)
#    1239 (2, 1, 4)
#    1240 """
#    1241 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1242 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\.conda\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
if optimal_cost:
    print(f'Optimal cost: {optimal_cost}')
    print(f'Best cost: {results["global_best_solution"]["cost"]}')
    print(f'Difference %: {round((results["global_best_solution"]["cost"] - optimal_cost) / optimal_cost * 100, 2)}')
    
if PLOT_SOLUTION:
    instance_name = INSTANCE.split('/')[-1]
    DisplayModel.render_solution(results['global_best_solution'], matrix_coords, instance_name,
                                 results['best_solutions'], results['iterations_mean_costs'], results['iterations_median_costs'])
# Out:
# Optimal cost: 826.137
# Best cost: 1028.3907065674146
# Difference %: 24.48
