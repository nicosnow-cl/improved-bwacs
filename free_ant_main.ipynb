# %%
# %config IPCompleter.greedy=True
from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 100% !important; }</style>"))
# Out:
# <style>.container { width: 100% !important; }</style>

# %%
import os
from datetime import datetime
from free_bwacs_model import FreeBWACS
# %matplotlib inline

solutions_list = []
max_runs = 10
dct_with_header = False
save_results = True
_instance = 'CMT1'
_cluster_type = 'K-MEANS'

# Creación del archivo de texto plano con los resultados
now = datetime.now()
dt_string = now.strftime('%Y%m%d_%H-%M-%S')
aco_cluster = 'Free Ant + ' + _cluster_type  # Titulo del archivo .txt
# FA o RA (FREE ANT - RESTRICTED ANT) para el titulo del archivo
ant_type = 'FA'
# KMEN o KMED (K-MEANS - K-MEDOIDS) para el titulo del archivo
cluster_type = _cluster_type.replace('-', '').upper()[0:4]
instance = _instance
file_folder = 'instances_results/' + instance
file_folder_img = 'instances_results/' + instance + '/img_results'
if not os.path.exists(file_folder):
    os.makedirs(file_folder)
if not os.path.exists(file_folder_img):
    os.makedirs(file_folder_img)
file_name = ant_type + '_' + cluster_type + '_' + dt_string + '.txt'

for run in range(max_runs):
    aco_model = FreeBWACS(
        # Instance path + filename
        instance='CVRPLIB/CMT/' + _instance,
        # Max nodes selected
        max_nodes=9999,
        # Cluster type - options: | kmedoids - kmeans |
        cluster_type=_cluster_type.replace('-', '').lower(),
        # Metric distance - options: | euclidian - manhattan |
        metric='euclidian',
        # Tare for the heterogenoeus vehicles, this value is a percentage used by the next function: Vehicle Weight = Max Capacity * tare
        tare_percentage=0.15,
        # Max number of iterations
        max_iterations=100,
        # Define the total number of ants per iteration, through the next function: Total Ant = Total Nodes / total_ant_divider
        total_ant_divider=1,
        # Only accept solutions with the numbers of routes equal to K-Optimum - options: | True - False |
        only_k_optimum=True,
        # Place each ant in a different node of the candidate node list. Otherwise each ant will start its journey in the depot node.
        # options: | True - False |
        start_ant_on_best_nodes=True,
        # heuristic_type will let you choice what information gotta build the heuristic information matrix
        # 0 - Only distances data / Best beta: 5
        # 1 - Only energies data / Best gamma: 5
        # 2 - Distances data * energies data / Best parameters: 5 - 5
        # 3 - Only distances data of Savings algorithm / Best delta: 1
        # 4 - Only energies data of Savings algorithm / Best eta: 2
        # 5 - Distances data * distances savings data / Best parameters: 4 - 5
        # 6 - Energies data * energies savings data / Best parameters: 5 - 5
        # 7 - Distances data * energies data * distances savings data / Best parameters: 3 - 4 - 3
        # 8 - Distances data * energies data * energies savings data / Best parameters: 3 - 4 - 3
        # 9 - Distances data * energies data * distances savings data * capacity utilization data / Best parameters: 2 - 4 - 4 - 2
        # 10 - Distances data * energies data * distances savings data * capacity utilization data / Best parameters: 2 - 4 - 4 - 2
        # 11 - Distances data * energies data * distances savings data * energies savings data * capacity utilization data / Best parameters: 2 - 4 - 3 - 4 - 1
        heuristic_type=8,
        # Importance of pheromones trace. Recommended alpha value in: [1, 4]
        alpha=3,
        # Importance of distance heuristic information. Recommended beta value in: [2, 5]
        beta=2,
        # Importance of energy heuristic information. Recommended gamma value in: [2, 5]
        gamma=3,
        # Importance of distances's Savings Algorithm information. Recommended delta value in: [0, 2]
        delta=1,
        # Importance of energies's Savings Algorithm information. Recommended eta value in: [0, 2]
        eta=1,
        # Importance of vehicle's capacity utilization. Recommended mi value in: [0, 2]
        mi=0,
        # Define the strategy used for pheromone updating. - options: | 0 - 1 |
        # The value 0 is for the classic function in ACO: 1 / Best_Solution_Quality
        # The value 1 if for the improve function know as Ant Weight Strategy.
        pheromone_updating_strategy=0,
        # Determine if every single ant can update the pheromones whit - options: | True - False |
        local_ant_update_pheromones=False,
        # Determine if the best ant of current iteration can update the pheromones - options: | True - False |
        best_iteration_ant_update_pheromones=False,
        # Determine if the best global ant can update the pheromones - options: | True - False |
        best_global_ant_update_pheromones=True,
        # Defines if the worst solution of the current iteration should penalize the pheromone arcs. - options: | True - False |
        penalize_worst_solution=True,
        # Want to mutate the pheromones matrix? - options: | True - False |
        mutate_pheromones_matrix=True,
        # Evaporation rate of the pheromones by the next function: phoromone =  (1 - p) * pheromone. Recommended value for p: 0.02.
        p=0.02,
        # Mutation probability for every row of the pheromones matrix, such as: mutate if (random number between 0 and 1) <= Pm
        # Recommended value for Pm: 0.3.
        Pm=0.3,
        # Mutation intensity for the pheromones matrix. Recommended value for sigma in: [2, 4]
        sigma=4,
        # Constant used in Pseudorandom Transition Rule. This is a probability of choice the next node by argmax, define in Ant Colony System.
        # Recommended value for l0 in: [0.2, 0.4]
        l0=0.3,
        # Constant used for a lot of functions, such as: f(.) = H / specific_values.
        H=1,
        # Want to do a Local Search to the solution of every single ant? - options: | True - False |
        ls_ant_solution=False,
        # Want to do a Local Search to the best iteration solution? - options: | True - False |
        ls_best_iteration=False,
        # Want to do a Local Search to the best global solution? - options: | True - False |
        ls_best_global=False,
        # Want to use the Normalized Matrix? - options: | True - False |
        use_normalized_matrix=False,
        # Use Matplotlib to draw a 2-D graph with the nodes of the problem. - option: | True - False |
        print_instance=False,
        # Use Matplotlib to draw the solution of clustering process. - option: | True - False |
        print_clusters=False,
        # Use Matplotlib to draw the final solution of the problem. - option: | True - False |
        print_solution=False,
        # Show the distance matrix in a html table. - option: | True - False |
        print_distance_matrix=False,
        # Show the energy matrix in a html table. - option: | True - False |
        print_energy_matrix=False,
        # Show the distance savings matrix in a html table. - option: | True - False |
        print_distance_saving_matrix=False,
        # Show the energy savings matrix in a html table. - option: | True - False |
        print_energy_saving_matrix=False,
        # Show the final heuristic matrix in a html table. - option: | True - False |
        print_combination_matrix=False,
        # Show the pheromone matrix in a html table. - option: | True - False |
        print_pheromone_matrix=False,
        # Output folder/name solution draw
        output_sol_img=file_folder_img + '/' + \
        str(run + 1) + '__' + ant_type + '_' + \
        cluster_type + '_' + dt_string + '.png'
    )

    solution_energy, solution_distance, solution_time = aco_model.solve()
    solutions_list.append((solution_energy, solution_distance, solution_time))

print(solutions_list)
print("Best Solution: " + str(min(solutions_list, key=lambda x: x[0])) + " on run: " + str(solutions_list.index(min(solutions_list, key=lambda x: x[0])) + 1))

if (save_results):
    file = open(file_folder + '/' + file_name, 'a')
    if dct_with_header:
        file.write('Resultados para la ' + instance + ' (' +
                aco_cluster + ') [energia, distancia, tiempo de ejecución]\n\n')
    for i, solution in enumerate(solutions_list):
        if dct_with_header:
            file.write(str(i + 1) + '| ' + str(solution) + '\n')
        else:
            str_sol = str(solution).replace('(', '').replace(')',
                                                            '').replace(',', '').replace('.', ',')
            file.write(str_sol + '\n')

    file.close()
# Out:
# • INITIALIZING ALGORITHM •
# ------------------------------
#
# • 0. Reading instance file
# ------------------------------
#
#     - Parameters:
#         > Instance name: CVRPLIB/CMT/CMT1
#         > Number of nodes: 51
#         > Nodes and demands: {0: 0, 1: 7, 2: 30, 3: 16, 4: 9, 5: 21, 6: 15, 7: 19, 8: 23, 9: 11, 10: 5, 11: 19, 12: 29, 13: 23, 14: 21, 15: 10, 16: 15, 17: 3, 18: 41, 19: 9, 20: 28, 21: 8, 22: 8, 23: 16, 24: 10, 25: 28, 26: 7, 27: 15, 28: 14, 29: 6, 30: 19, 31: 11, 32: 12, 33: 23, 34: 26, 35: 17, 36: 6, 37: 9, 38: 15, 39: 14, 40: 7, 41: 27, 42: 13, 43: 11, 44: 16, 45: 10, 46: 5, 47: 25, 48: 17, 49: 18, 50: 10}
#         > Total demand: 777 units
#         > Vehicles capacity: 160 units
#         > K-Optimum: 5
#         > Tightness ratio: 0.97125
#         > Total of iterations: 100
#         > Number of ants per iteration: 50
#
# • 1. Starting clustering process
# ------------------------------
#
#     > CLUSTER TYPE: KMEANS
#     > ITERACIÓN 1
#         - Centroides actuales: [array([57, 58]), array([17, 33]), array([10, 17]), array([61, 33]), array([ 7, 38])]
#         - Nodos sin asignar: [ 7 30], [23 11]
#         - Mejor costo anterior: inf
#         - Costo total actual: 9739.5597891085
#
#     > ITERACIÓN 2
#         - Centroides actuales: [array([37., 69.]), array([29.11111111, 31.44444444]), array([22.77777778, 13.55555556]), array([54.4, 31.2]), array([16.8, 53.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 9739.5597891085
#         - Costo total actual: 9469.008712103712
#
#     > ITERACIÓN 3
#         - Centroides actuales: [array([41.3, 59.2]), array([32.44444444, 33.77777778]), array([21.22222222, 14.88888889]), array([46., 10.]), array([20.4, 53.5])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 10376.00191633337
#
#     > ITERACIÓN 4
#         - Centroides actuales: [array([63., 69.]), array([39.3, 34.7]), array([21., 21.]), array([50.        , 22.33333333]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 9382.963165716292
#
#     > ITERACIÓN 5
#         - Centroides actuales: [array([52.5, 58.6]), array([39.8, 38.5]), array([18., 19.]), array([50.        , 21.44444444]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 9382.963165716292
#         - Costo total actual: 9131.213913563224
#
#     > ITERACIÓN 6
#         - Centroides actuales: [array([27., 68.]), array([40.3, 40.1]), array([20.8, 21.9]), array([48.1, 25.5]), array([ 5., 64.])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 12447.104568066417
#
#     > ITERACIÓN 7
#         - Centroides actuales: [array([40.54545455, 57.        ]), array([44.6, 42.5]), array([20. , 19.7]), array([50.7, 25. ]), array([17.        , 50.11111111])]
#         - Nodos sin asignar: [12], [23]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9205.552639738571
#
#     > ITERACIÓN 8
#         - Centroides actuales: [array([43.8, 61.5]), array([47.        , 39.45454545]), array([ 5., 25.]), array([50.11111111, 23.66666667]), array([15.66666667, 51.77777778])]
#         - Nodos sin asignar: [11], [29]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9274.450376400218
#
#     > ITERACIÓN 9
#         - Centroides actuales: [array([43.72727273, 58.54545455]), array([31., 32.]), array([12.25, 21.  ]), array([45.18181818, 21.36363636]), array([17.66666667, 51.11111111])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 10115.12837053417
#
#     > ITERACIÓN 10
#         - Centroides actuales: [array([44.4, 57.2]), array([40.09090909, 35.54545455]), array([12.25, 21.  ]), array([49. , 22.3]), array([25.36363636, 54.18181818])]
#         - Nodos sin asignar: [43], [16]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 8770.75270035537
#
#     > ITERACIÓN 11
#         - Centroides actuales: [array([51.09090909, 58.        ]), array([39.3, 35.5]), array([30., 15.]), array([50.        , 21.44444444]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9769.457396640944
#
#     > ITERACIÓN 12
#         - Centroides actuales: [array([51.44444444, 58.55555556]), array([40.4, 40.7]), array([24.5, 18.5]), array([44.1, 23.5]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9149.19296884423
#
#     > ITERACIÓN 13
#         - Centroides actuales: [array([27., 68.]), array([38.8, 42.6]), array([21.4, 22.6]), array([49. , 22.3]), array([ 5., 64.])]
#         - Nodos sin asignar: [20], [8]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 11671.139732542391
#
#     > ITERACIÓN 14
#         - Centroides actuales: [array([43.9, 63.2]), array([62., 42.]), array([20. , 19.7]), array([49. , 22.3]), array([16.55555556, 48.44444444])]
#         - Nodos sin asignar: [39], [7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10696.56634254118
#
#     > ITERACIÓN 15
#         - Centroides actuales: [array([41.16666667, 61.58333333]), array([47.77777778, 39.        ]), array([5., 6.]), array([46. , 22.2]), array([18.66666667, 49.        ])]
#         - Nodos sin asignar: [46], [25]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10035.503670792263
#
#     > ITERACIÓN 16
#         - Centroides actuales: [array([45.1, 62.9]), array([51.5, 40.5]), array([16.44444444, 18.66666667]), array([44. , 21.1]), array([25., 32.])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10623.636803568075
#
#     > ITERACIÓN 17
#         - Centroides actuales: [array([41.41666667, 60.58333333]), array([53.6, 37.4]), array([15.22222222, 25.44444444]), array([40.        , 28.88888889]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9746.613717133847
#
#     > ITERACIÓN 18
#         - Centroides actuales: [array([44.9, 59.3]), array([54.63636364, 37.09090909]), array([15.88888889, 20.55555556]), array([46., 10.]), array([15.33333333, 54.        ])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9550.93543363689
#
#     > ITERACIÓN 19
#         - Centroides actuales: [array([63., 69.]), array([54.8, 40. ]), array([18.88888889, 22.33333333]), array([38.5, 18.3]), array([17.3, 50.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10439.904257073627
#
#     > ITERACIÓN 20
#         - Centroides actuales: [array([47.3, 61. ]), array([48.09090909, 35.36363636]), array([18.88888889, 24.22222222]), array([41.2, 19.9]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24 25], [28  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 8306.319175559167
#
#     > ITERACIÓN 21
#         - Centroides actuales: [array([50. , 59.6]), array([51.4, 36.3]), array([ 7., 38.]), array([36.9, 17.7]), array([27., 68.])]
#         - Nodos sin asignar: [38 18], [14  9]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 10173.537298092959
#
#     > ITERACIÓN 22
#         - Centroides actuales: [array([50.11111111, 56.33333333]), array([47.18181818, 33.54545455]), array([15.25, 37.75]), array([13., 13.]), array([23.5, 55.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9888.028925395214
#
#     > ITERACIÓN 23
#         - Centroides actuales: [array([51.18181818, 55.90909091]), array([50.5, 32.6]), array([17.55555556, 38.66666667]), array([22.4, 16.7]), array([30.2, 49.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8779.285862604613
#
#     > ITERACIÓN 24
#         - Centroides actuales: [array([52.81818182, 52.63636364]), array([46., 10.]), array([18.83333333, 37.33333333]), array([21.63636364, 16.63636364]), array([24.18181818, 55.09090909])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11160.760494587392
#
#     > ITERACIÓN 25
#         - Centroides actuales: [array([53.2, 50. ]), array([48.63636364, 29.63636364]), array([20.57142857, 34.57142857]), array([23.09090909, 23.90909091]), array([26.09090909, 56.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9326.960082949558
#
#     > ITERACIÓN 26
#         - Centroides actuales: [array([53.9, 53.2]), array([47.5, 32.3]), array([18.85714286, 38.28571429]), array([23.66666667, 16.08333333]), array([29.27272727, 57.63636364])]
#         - Nodos sin asignar: [12 32], [23 23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8422.104191179695
#
#     > ITERACIÓN 27
#         - Centroides actuales: [array([49.54545455, 51.27272727]), array([46., 10.]), array([ 5., 25.]), array([25.33333333, 16.88888889]), array([25.6, 57. ])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11012.655751743518
#
#     > ITERACIÓN 28
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([49. , 22.3]), array([ 9.85714286, 24.85714286]), array([35.27272727, 33.27272727]), array([23.63636364, 59.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9547.94009204571
#
#     > ITERACIÓN 29
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([52.27272727, 29.54545455]), array([12.        , 27.71428571]), array([28.90909091, 26.54545455]), array([23. , 60.4])]
#         - Nodos sin asignar: [27 35], [14  6]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8066.528567941032
#
#     > ITERACIÓN 30
#         - Centroides actuales: [array([63., 69.]), array([52.45454545, 26.45454545]), array([12.        , 27.71428571]), array([27.9, 22.5]), array([21.7, 58.5])]
#         - Nodos sin asignar: [32 10], [23 19]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9162.6705524307
#
#     > ITERACIÓN 31
#         - Centroides actuales: [array([48.18181818, 53.81818182]), array([42., 41.]), array([12.        , 27.71428571]), array([31.3, 22.9]), array([23.18181818, 55.81818182])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9781.030433449172
#
#     > ITERACIÓN 32
#         - Centroides actuales: [array([47.90909091, 55.09090909]), array([49.63636364, 36.54545455]), array([12.71428571, 25.28571429]), array([31.5, 18.1]), array([25.        , 53.09090909])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8647.195431821801
#
#     > ITERACIÓN 33
#         - Centroides actuales: [array([63., 69.]), array([50.5, 32.6]), array([12.        , 27.71428571]), array([31.90909091, 17.36363636]), array([22.72727273, 54.63636364])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10224.697698766111
#
#     > ITERACIÓN 34
#         - Centroides actuales: [array([53.09090909, 54.63636364]), array([48.63636364, 34.63636364]), array([12.71428571, 25.28571429]), array([29.09090909, 22.27272727]), array([22.4, 54.6])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8205.405893565472
#
#     > ITERACIÓN 35
#         - Centroides actuales: [array([51.18181818, 57.45454545]), array([59., 15.]), array([12.        , 27.71428571]), array([29.2, 17.6]), array([22.63636364, 55.18181818])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9840.425181254781
#
#     > ITERACIÓN 36
#         - Centroides actuales: [array([51.6, 56.2]), array([53. , 31.5]), array([12.71428571, 25.28571429]), array([32.33333333, 23.83333333]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9209.872196275994
#
#     > ITERACIÓN 37
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([53.27272727, 32.09090909]), array([12.        , 27.71428571]), array([46., 10.]), array([18.5, 52.2])]
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:401: RuntimeWarning: divide by zero encountered in true_divide
#   self.distances_matrix_normalized = self.np.divide(1, self.distances_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:418: RuntimeWarning: divide by zero encountered in true_divide
#   self.energies_matrix_normalized = self.np.divide(1, self.energies_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:546: RuntimeWarning: divide by zero encountered in true_divide
#   _distance_matrix = self.np.power(self.np.divide(1, self.distances_matrix), self.beta)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:547: RuntimeWarning: divide by zero encountered in true_divide
#   _energy_matrix = self.np.power(self.np.divide(1, self.energies_matrix), self.gamma)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:550: RuntimeWarning: invalid value encountered in multiply
#   self.combination_matrix = self.np.multiply(self.combination_matrix, _saving_energies_matrix)
#         - Nodos sin asignar: [18 39], [9 7]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8682.729335656946
#
#     > ITERACIÓN 38
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([5., 6.]), array([38.5, 18.1]), array([19.2, 55.8])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9938.838033288544
#
#     > ITERACIÓN 39
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([12.25, 21.  ]), array([59., 15.]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24 42], [28 11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8844.914022470824
#
#     > ITERACIÓN 40
#         - Centroides actuales: [array([48.36363636, 57.72727273]), array([46.6, 36.5]), array([ 7., 38.]), array([45.77777778, 18.77777778]), array([ 5., 64.])]
#         - Nodos sin asignar: [40], [27]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10771.024281503887
#
#     > ITERACIÓN 41
#         - Centroides actuales: [array([48.18181818, 52.27272727]), array([46.33333333, 36.44444444]), array([10., 17.]), array([42. , 17.4]), array([20.4, 53.5])]
#         - Nodos sin asignar: [30], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9760.871029384165
#
#     > ITERACIÓN 42
#         - Centroides actuales: [array([37., 69.]), array([48.6, 34.4]), array([19.88888889, 25.66666667]), array([35.8, 20.2]), array([19.2, 55.8])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 
), (6, 32), (6, 31), (6, 28), (7, 48), (7, 8), (7, 27), (7, 23), (7, 6), (7, 1), (7, 26), (7, 32), (7, 31), (7, 28), (1, 48), (1, 8), (1, 27), (1, 23), (1, 6), (1, 7), (1, 26), (1, 32), (1, 31), (1, 28), (26, 48), (26, 8), (26, 27), (26, 23), (26, 6), (26, 7), (26, 1), (26, 32), (26, 31), (26, 28), (32, 48), (32, 8), (32, 27), (32, 23), (32, 6), (32, 7), (32, 1), (32, 26), (32, 31), (32, 28), (31, 48), (31, 8), (31, 27), (31, 23), (31, 6), (31, 7), (31, 1), (31, 26), (31, 32), (31, 28), (28, 48), (28, 8), (28, 27), (28, 23), (28, 6), (28, 7), (28, 1), (28, 26), (28, 32), (28, 31)]
#     • Preliminar parameters:
#         > Tmin value: 2.1068781023028867e-14
#         > Tmax value: 2.1068781023028865e-11
#         > Initial candidate list: [10, 4, 45, 3, 26, 16, 47, 13, 5, 32, 33, 29, 2, 20, 27, 14, 23, 24, 37, 7, 41, 40, 8, 34, 28, 19, 1, 42, 25, 43, 21, 22, 38, 31, 18, 9, 30, 39, 11, 35, 49, 36, 6, 44, 15, 48, 12, 17, 50, 46]
#
#
#     • Iteration 1
#         > Mean quality of the solutions in this iteration : 87354.76634079093
#         + New best energy: 67403, with the next distance: 649
#
#     • Iteration 2
#         > Mean quality of the solutions in this iteration : 86170.45192761275
#
#     • Iteration 3
#         > Mean quality of the solutions in this iteration : 88024.03969755379
#         + New best energy: 60822, with the next distance: 676
#
#     • Iteration 4
#         > Mean quality of the solutions in this iteration : 89196.17253739126
#
#     • Iteration 5
#         > Mean quality of the solutions in this iteration : 87444.1399872098
#
#     • Iteration 6
#         > Mean quality of the solutions in this iteration : 86754.85494059304
#
#     • Iteration 7
#         > Mean quality of the solutions in this iteration : 86601.70810240526
#
#     • Iteration 8
#         > Mean quality of the solutions in this iteration : 87097.59140130533
#
#     • Iteration 9
#         > Mean quality of the solutions in this iteration : 86948.47600367172
#
#     • Iteration 10
#         > Mean quality of the solutions in this iteration : 87000.96426007956
#
#     • Iteration 11
#         > Mean quality of the solutions in this iteration : 86744.94474734088
#
#     • Iteration 12
#         > Mean quality of the solutions in this iteration : 85823.60513709833
#
#     • Iteration 13
#         > Mean quality of the solutions in this iteration : 88585.64550684918
#
#     • Iteration 14
#         > Mean quality of the solutions in this iteration : 86068.27376839185
#
#     • Iteration 15
#         > Mean quality of the solutions in this iteration : 89035.62795915658
#
#     • Iteration 16
#         > Mean quality of the solutions in this iteration : 86700.69568610047
#
#     • Iteration 17
#         > Mean quality of the solutions in this iteration : 87489.78187420972
#
#     • Iteration 18
#         > Mean quality of the solutions in this iteration : 87688.29109404054
#
#     • Iteration 19
#         > Mean quality of the solutions in this iteration : 87092.31247890147
#
#     • Iteration 20
#         > Mean quality of the solutions in this iteration : 88989.3744290737
#
#     • Iteration 21
#         > Mean quality of the solutions in this iteration : 87219.35632907564
#
#     • Iteration 22
#         > Mean quality of the solutions in this iteration : 89291.84014000771
#
#     • Iteration 23
#         > Mean quality of the solutions in this iteration : 86746.90611518493
#
#     • Iteration 24
#         > Mean quality of the solutions in this iteration : 91066.89601416978
#
#     • Iteration 25
#         > Mean quality of the solutions in this iteration : 89140.79570151554
#
#     • Iteration 26
#         > Mean quality of the solutions in this iteration : 89411.53951899016
#
#     • Iteration 27
#         > Mean quality of the solutions in this iteration : 84574.91231846221
#
#     • Iteration 28
#         > Mean quality of the solutions in this iteration : 86956.66633654744
#
#     • Iteration 29
#         > Mean quality of the solutions in this iteration : 87462.23907436377
#
#     • Iteration 30
#         > Mean quality of the solutions in this iteration : 87195.26382010954
#
#     • Iteration 31
#         > Mean quality of the solutions in this iteration : 89224.71814227535
#
#     • Iteration 32
#         > Mean quality of the solutions in this iteration : 86749.99475365577
#
#     • Iteration 33
#         > Mean quality of the solutions in this iteration : 89694.54768129779
#
#     • Iteration 34
#         > Mean quality of the solutions in this iteration : 88790.68442776814
#         - The Pheromone Matrix has been restarted.
#
#     • Iteration 35
#         > Mean quality of the solutions in this iteration : 85527.36932737641
#
#     • Iteration 36
#         > Mean quality of the solutions in this iteration : 88696.2926094927
#
#     • Iteration 37
#         > Mean quality of the solutions in this iteration : 87921.36950181698
#
#     • Iteration 38
#         > Mean quality of the solutions in this iteration : 87630.16077812966
#
#     • Iteration 39
#         > Mean quality of the solutions in this iteration : 86034.76585313331
#
#     • Iteration 40
#         > Mean quality of the solutions in this iteration : 85658.01907885476
#
#     • Iteration 41
#         > Mean quality of the solutions in this iteration : 86200.45229603024
#
#     • Iteration 42
#         > Mean quality of the solutions in this iteration : 86054.6849718392
#
#     • Iteration 43
#         > Mean quality of the solutions in this iteration : 87740.53846081265
#
#     • Iteration 44
#         > Mean quality of the solutions in this iteration : 88938.65017597233
#
#     • Iteration 45
#         > Mean quality of the solutions in this iteration : 89003.74460256235
#
#     • Iteration 46
#         > Mean quality of the solutions in this iteration : 85786.26822314766
#
#     • Iteration 47
#         > Mean quality of the solutions in this iteration : 88132.38339414488
#
#     • Iteration 48
#         > Mean quality of the solutions in this iteration : 89848.08064488022
#
#     • Iteration 49
#         > Mean quality of the solutions in this iteration : 87875.17122318083
#
#     • Iteration 50
#         > Mean quality of the solutions in this iteration : 86404.70476200653
#
#     • Iteration 51
#         > Mean quality of the solutions in this iteration : 89017.43910841702
#
#     • Iteration 52
#         > Mean quality of the solutions in this iteration : 85521.58294002313
#
#     • Iteration 53
#         > Mean quality of the solutions in this iteration : 90769.05520936202
#
#     • Iteration 54
#         > Mean quality of the solutions in this iteration : 89314.244875051
#
#     • Iteration 55
#         > Mean quality of the solutions in this iteration : 90186.41367406184
#
#     • Iteration 56
#         > Mean quality of the solutions in this iteration : 90955.46592735645
#
#     • Iteration 57
#         > Mean quality of the solutions in this iteration : 89895.77276414764
#
#     • Iteration 58
#         > Mean quality of the solutions in this iteration : 88292.3983827115
#
#     • Iteration 59
#         > Mean quality of the solutions in this iteration : 89032.11428922106
#
#     • Iteration 60
#         > Mean quality of the solutions in this iteration : 92338.30877689498
#
#     • Iteration 61
#         > Mean quality of the solutions in this iteration : 92722.46008381751
#
#     • Iteration 62
#         > Mean quality of the solutions in this iteration : 91133.6565215356
#
#     • Iteration 63
#         > Mean quality of the solutions in this iteration : 89709.00027289116
#
#     • Iteration 64
#         > Mean quality of the solutions in this iteration : 87130.95117499401
#
#     • Iteration 65
#         > Mean quality of the solutions in this iteration : 90487.98403052766
#         - The Pheromone Matrix has been restarted.
#
#     • Iteration 66
#         > Mean quality of the solutions in this iteration : 87540.02229785472
#
#     • Iteration 67
#         > Mean quality of the solutions in this iteration : 86928.19132338776
#
#     • Iteration 68
#         > Mean quality of the solutions in this iteration : 85688.42468360503
#
#     • Iteration 69
#         > Mean quality of the solutions in this iteration : 86729.10766250447
#
#     • Iteration 70
#         > Mean quality of the solutions in this iteration : 85629.36521892609
#
#     • Iteration 71
#         > Mean quality of the solutions in this iteration : 86112.43591203092
#
#     • Iteration 72
#         > Mean quality of the solutions in this iteration : 88201.72270264072
#
#     • Iteration 73
#         > Mean quality of the solutions in this iteration : 87965.82010189908
#
#     • Iteration 74
#         > Mean quality of the solutions in this iteration : 87500.76628455198
#
#     • Iteration 75
#         > Mean quality of the solutions in this iteration : 86424.06870473815
#
#     • Iteration 76
#         > Mean quality of the solutions in this iteration : 86651.91124875931
#
#     • Iteration 77
#         > Mean quality of the solutions in this iteration : 87872.77960866567
#
#     • Iteration 78
#         > Mean quality of the solutions in this iteration : 89088.50505583512
#
#     • Iteration 79
#         > Mean quality of the solutions in this iteration : 88743.61353403471
#
#     • Iteration 80
#         > Mean quality of the solutions in this iteration : 87315.78822403144
#
#     • Iteration 81
#         > Mean quality of the solutions in this iteration : 87704.05511293738
#
#     • Iteration 82
#         > Mean quality of the solutions in this iteration : 86572.04043931101
#
#     • Iteration 83
#         > Mean quality of the solutions in this iteration : 87604.91494040133
#
#     • Iteration 84
#         > Mean quality of the solutions in this iteration : 88659.17508753411
#
#     • Iteration 85
#         > Mean quality of the solutions in this iteration : 87106.47764014281
#
#     • Iteration 86
#         > Mean quality of the solutions in this iteration : 87081.3119319812
#
#     • Iteration 87
#         > Mean quality of the solutions in this iteration : 87047.41601323197
#
#     • Iteration 88
#         > Mean quality of the solutions in this iteration : 91517.60945154475
#
#     • Iteration 89
#         > Mean quality of the solutions in this iteration : 88281.61802345375
#
#     • Iteration 90
#         > Mean quality of the solutions in this iteration : 87837.45918470214
#
#     • Iteration 91
#         > Mean quality of the solutions in this iteration : 88682.94958652844
#
#     • Iteration 92
#         > Mean quality of the solutions in this iteration : 87496.4427446513
#
#     • Iteration 93
#         > Mean quality of the solutions in this iteration : 89868.56951959818
#
#     • Iteration 94
#         > Mean quality of the solutions in this iteration : 86612.06938819053
#
#     • Iteration 95
#         > Mean quality of the solutions in this iteration : 87031.1509025065
#
#     • Iteration 96
#         > Mean quality of the solutions in this iteration : 90441.68656814224
#         - The Pheromone Matrix has been restarted.
#
#     • Iteration 97
#         > Mean quality of the solutions in this iteration : 86679.38946679559
#
#     • Iteration 98
#         > Mean quality of the solutions in this iteration : 86799.45806652811
#
#     • Iteration 99
#         > Mean quality of the solutions in this iteration : 86860.84519787706
#
#     • Iteration 100
#         > Mean quality of the solutions in this iteration : 89082.66850553358
#
#     • Global best routes:
#         - Route 0: [0, 17, 37, 15, 44, 45, 33, 10, 30, 34, 50, 9, 38, 0], with final total demand: 157
#         - Route 1: [0, 28, 31, 8, 26, 7, 23, 6, 48, 27, 1, 32, 0], with final total demand: 156
#         - Route 2: [0, 40, 19, 41, 42, 4, 18, 47, 12, 0], with final total demand: 160
#         - Route 3: [0, 16, 29, 21, 2, 22, 3, 20, 35, 36, 11, 46, 0], with final total demand: 158
#         - Route 4: [0, 39, 49, 5, 13, 25, 14, 24, 43, 0], with final total demand: 146
#         - Final total energy: 60822.48338681596
#         - Final total distance: 676.3358812031227
#         - Total time: 3.297027826309204 seconds.
#
#
# • INITIALIZING ALGORITHM •
# ------------------------------
#
# • 0. Reading instance file
# ------------------------------
#
#     - Parameters:
#         > Instance name: CVRPLIB/CMT/CMT1
#         > Number of nodes: 51
#         > Nodes and demands: {0: 0, 1: 7, 2: 30, 3: 16, 4: 9, 5: 21, 6: 15, 7: 19, 8: 23, 9: 11, 10: 5, 11: 19, 12: 29, 13: 23, 14: 21, 15: 10, 16: 15, 17: 3, 18: 41, 19: 9, 20: 28, 21: 8, 22: 8, 23: 16, 24: 10, 25: 28, 26: 7, 27: 15, 28: 14, 29: 6, 30: 19, 31: 11, 32: 12, 33: 23, 34: 26, 35: 17, 36: 6, 37: 9, 38: 15, 39: 14, 40: 7, 41: 27, 42: 13, 43: 11, 44: 16, 45: 10, 46: 5, 47: 25, 48: 17, 49: 18, 50: 10}
#         > Total demand: 777 units
#         > Vehicles capacity: 160 units
#         > K-Optimum: 5
#         > Tightness ratio: 0.97125
#         > Total of iterations: 100
#         > Number of ants per iteration: 50
#
# • 1. Starting clustering process
# ------------------------------
#
#     > CLUSTER TYPE: KMEANS
#     > ITERACIÓN 1
#         - Centroides actuales: [array([57, 58]), array([17, 33]), array([10, 17]), array([61, 33]), array([ 7, 38])]
#         - Nodos sin asignar: [ 7 30], [23 11]
#         - Mejor costo anterior: inf
#         - Costo total actual: 9739.5597891085
#
#     > ITERACIÓN 2
#         - Centroides actuales: [array([37., 69.]), array([29.11111111, 31.44444444]), array([22.77777778, 13.55555556]), array([54.4, 31.2]), array([16.8, 53.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 9739.5597891085
#         - Costo total actual: 9469.008712103712
#
#     > ITERACIÓN 3
#         - Centroides actuales: [array([41.3, 59.2]), array([32.44444444, 33.77777778]), array([21.22222222, 14.88888889]), array([46., 10.]), array([20.4, 53.5])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 10376.00191633337
#
#     > ITERACIÓN 4
#         - Centroides actuales: [array([63., 69.]), array([39.3, 34.7]), array([21., 21.]), array([50.        , 22.33333333]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 9469.008712103712
#         - Costo total actual: 9382.963165716292
#
#     > ITERACIÓN 5
#         - Centroides actuales: [array([52.5, 58.6]), array([39.8, 38.5]), array([18., 19.]), array([50.        , 21.44444444]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 9382.963165716292
#         - Costo total actual: 9131.213913563224
#
#     > ITERACIÓN 6
#         - Centroides actuales: [array([27., 68.]), array([40.3, 40.1]), array([20.8, 21.9]), array([48.1, 25.5]), array([ 5., 64.])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 12447.104568066417
#
#     > ITERACIÓN 7
#         - Centroides actuales: [array([40.54545455, 57.        ]), array([44.6, 42.5]), array([20. , 19.7]), array([50.7, 25. ]), array([17.        , 50.11111111])]
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:401: RuntimeWarning: divide by zero encountered in true_divide
#   self.distances_matrix_normalized = self.np.divide(1, self.distances_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:418: RuntimeWarning: divide by zero encountered in true_divide
#   self.energies_matrix_normalized = self.np.divide(1, self.energies_matrix)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:546: RuntimeWarning: divide by zero encountered in true_divide
#   _distance_matrix = self.np.power(self.np.divide(1, self.distances_matrix), self.beta)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:547: RuntimeWarning: divide by zero encountered in true_divide
#   _energy_matrix = self.np.power(self.np.divide(1, self.energies_matrix), self.gamma)
# e:\0 - PROYECTOS\1 - PERSONALES\BWACS-EMVRP\improved-bwacs\free_bwacs_model.py:550: RuntimeWarning: invalid value encountered in multiply
#   self.combination_matrix = self.np.multiply(self.combination_matrix, _saving_energies_matrix)
#         - Nodos sin asignar: [12], [23]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9205.552639738571
#
#     > ITERACIÓN 8
#         - Centroides actuales: [array([43.8, 61.5]), array([47.        , 39.45454545]), array([ 5., 25.]), array([50.11111111, 23.66666667]), array([15.66666667, 51.77777778])]
#         - Nodos sin asignar: [11], [29]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 9274.450376400218
#
#     > ITERACIÓN 9
#         - Centroides actuales: [array([43.72727273, 58.54545455]), array([31., 32.]), array([12.25, 21.  ]), array([45.18181818, 21.36363636]), array([17.66666667, 51.11111111])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 10115.12837053417
#
#     > ITERACIÓN 10
#         - Centroides actuales: [array([44.4, 57.2]), array([40.09090909, 35.54545455]), array([12.25, 21.  ]), array([49. , 22.3]), array([25.36363636, 54.18181818])]
#         - Nodos sin asignar: [43], [16]
#         - Mejor costo anterior: 9131.213913563224
#         - Costo total actual: 8770.75270035537
#
#     > ITERACIÓN 11
#         - Centroides actuales: [array([51.09090909, 58.        ]), array([39.3, 35.5]), array([30., 15.]), array([50.        , 21.44444444]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24], [28]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9769.457396640944
#
#     > ITERACIÓN 12
#         - Centroides actuales: [array([51.44444444, 58.55555556]), array([40.4, 40.7]), array([24.5, 18.5]), array([44.1, 23.5]), array([ 7., 38.])]
#         - Nodos sin asignar: [ 6 42 25], [19 11  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9149.19296884423
#
#     > ITERACIÓN 13
#         - Centroides actuales: [array([27., 68.]), array([38.8, 42.6]), array([21.4, 22.6]), array([49. , 22.3]), array([ 5., 64.])]
#         - Nodos sin asignar: [20], [8]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 11671.139732542391
#
#     > ITERACIÓN 14
#         - Centroides actuales: [array([43.9, 63.2]), array([62., 42.]), array([20. , 19.7]), array([49. , 22.3]), array([16.55555556, 48.44444444])]
#         - Nodos sin asignar: [39], [7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10696.56634254118
#
#     > ITERACIÓN 15
#         - Centroides actuales: [array([41.16666667, 61.58333333]), array([47.77777778, 39.        ]), array([5., 6.]), array([46. , 22.2]), array([18.66666667, 49.        ])]
#         - Nodos sin asignar: [46], [25]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10035.503670792263
#
#     > ITERACIÓN 16
#         - Centroides actuales: [array([45.1, 62.9]), array([51.5, 40.5]), array([16.44444444, 18.66666667]), array([44. , 21.1]), array([25., 32.])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10623.636803568075
#
#     > ITERACIÓN 17
#         - Centroides actuales: [array([41.41666667, 60.58333333]), array([53.6, 37.4]), array([15.22222222, 25.44444444]), array([40.        , 28.88888889]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9746.613717133847
#
#     > ITERACIÓN 18
#         - Centroides actuales: [array([44.9, 59.3]), array([54.63636364, 37.09090909]), array([15.88888889, 20.55555556]), array([46., 10.]), array([15.33333333, 54.        ])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 9550.93543363689
#
#     > ITERACIÓN 19
#         - Centroides actuales: [array([63., 69.]), array([54.8, 40. ]), array([18.88888889, 22.33333333]), array([38.5, 18.3]), array([17.3, 50.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 10439.904257073627
#
#     > ITERACIÓN 20
#         - Centroides actuales: [array([47.3, 61. ]), array([48.09090909, 35.36363636]), array([18.88888889, 24.22222222]), array([41.2, 19.9]), array([16.8, 53.4])]
#         - Nodos sin asignar: [24 25], [28  7]
#         - Mejor costo anterior: 8770.75270035537
#         - Costo total actual: 8306.319175559167
#
#     > ITERACIÓN 21
#         - Centroides actuales: [array([50. , 59.6]), array([51.4, 36.3]), array([ 7., 38.]), array([36.9, 17.7]), array([27., 68.])]
#         - Nodos sin asignar: [38 18], [14  9]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 10173.537298092959
#
#     > ITERACIÓN 22
#         - Centroides actuales: [array([50.11111111, 56.33333333]), array([47.18181818, 33.54545455]), array([15.25, 37.75]), array([13., 13.]), array([23.5, 55.5])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9888.028925395214
#
#     > ITERACIÓN 23
#         - Centroides actuales: [array([51.18181818, 55.90909091]), array([50.5, 32.6]), array([17.55555556, 38.66666667]), array([22.4, 16.7]), array([30.2, 49.4])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8779.285862604613
#
#     > ITERACIÓN 24
#         - Centroides actuales: [array([52.81818182, 52.63636364]), array([46., 10.]), array([18.83333333, 37.33333333]), array([21.63636364, 16.63636364]), array([24.18181818, 55.09090909])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11160.760494587392
#
#     > ITERACIÓN 25
#         - Centroides actuales: [array([53.2, 50. ]), array([48.63636364, 29.63636364]), array([20.57142857, 34.57142857]), array([23.09090909, 23.90909091]), array([26.09090909, 56.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9326.960082949558
#
#     > ITERACIÓN 26
#         - Centroides actuales: [array([53.9, 53.2]), array([47.5, 32.3]), array([18.85714286, 38.28571429]), array([23.66666667, 16.08333333]), array([29.27272727, 57.63636364])]
#         - Nodos sin asignar: [12 32], [23 23]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8422.104191179695
#
#     > ITERACIÓN 27
#         - Centroides actuales: [array([49.54545455, 51.27272727]), array([46., 10.]), array([ 5., 25.]), array([25.33333333, 16.88888889]), array([25.6, 57. ])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 11012.655751743518
#
#     > ITERACIÓN 28
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([49. , 22.3]), array([ 9.85714286, 24.85714286]), array([35.27272727, 33.27272727]), array([23.63636364, 59.27272727])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 9547.94009204571
#
#     > ITERACIÓN 29
#         - Centroides actuales: [array([49.54545455, 48.63636364]), array([52.27272727, 29.54545455]), array([12.        , 27.71428571]), array([28.90909091, 26.54545455]), array([23. , 60.4])]
#         - Nodos sin asignar: [27 35], [14  6]
#         - Mejor costo anterior: 8306.319175559167
#         - Costo total actual: 8066.528567941032
#
#     > ITERACIÓN 30
#         - Centroides actuales: [array([63., 69.]), array([52.45454545, 26.45454545]), array([12.        , 27.71428571]), array([27.9, 22.5]), array([21.7, 58.5])]
#         - Nodos sin asignar: [32 10], [23 19]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9162.6705524307
#
#     > ITERACIÓN 31
#         - Centroides actuales: [array([48.18181818, 53.81818182]), array([42., 41.]), array([12.        , 27.71428571]), array([31.3, 22.9]), array([23.18181818, 55.81818182])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9781.030433449172
#
#     > ITERACIÓN 32
#         - Centroides actuales: [array([47.90909091, 55.09090909]), array([49.63636364, 36.54545455]), array([12.71428571, 25.28571429]), array([31.5, 18.1]), array([25.        , 53.09090909])]
#         - Nodos sin asignar: [35], [6]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8647.195431821801
#
#     > ITERACIÓN 33
#         - Centroides actuales: [array([63., 69.]), array([50.5, 32.6]), array([12.        , 27.71428571]), array([31.90909091, 17.36363636]), array([22.72727273, 54.63636364])]
#         - Nodos sin asignar: [], []
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 10224.697698766111
#
#     > ITERACIÓN 34
#         - Centroides actuales: [array([53.09090909, 54.63636364]), array([48.63636364, 34.63636364]), array([12.71428571, 25.28571429]), array([29.09090909, 22.27272727]), array([22.4, 54.6])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8205.405893565472
#
#     > ITERACIÓN 35
#         - Centroides actuales: [array([51.18181818, 57.45454545]), array([59., 15.]), array([12.        , 27.71428571]), array([29.2, 17.6]), array([22.63636364, 55.18181818])]
#         - Nodos sin asignar: [42], [11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9840.425181254781
#
#     > ITERACIÓN 36
#         - Centroides actuales: [array([51.6, 56.2]), array([53. , 31.5]), array([12.71428571, 25.28571429]), array([32.33333333, 23.83333333]), array([ 5., 64.])]
#         - Nodos sin asignar: [32], [23]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9209.872196275994
#
#     > ITERACIÓN 37
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([53.27272727, 32.09090909]), array([12.        , 27.71428571]), array([46., 10.]), array([18.5, 52.2])]
#         - Nodos sin asignar: [18 39], [9 7]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 8682.729335656946
#
#     > ITERACIÓN 38
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([5., 6.]), array([38.5, 18.1]), array([19.2, 55.8])]
#         - Nodos sin asignar: [38], [14]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual: 9938.838033288544
#
#     > ITERACIÓN 39
#         - Centroides actuales: [array([48.90909091, 58.36363636]), array([50.8, 35.6]), array([12.25, 21.  ]), array([59., 15.]), array([19.2, 55.8])]
#         - Nodos sin asignar: [24 42], [28 11]
#         - Mejor costo anterior: 8066.528567941032
#         - Costo total actual:
#     • Iteration 6
#         > Mean quality of the solutions in this iteration : 86481.73640374039
#
#     • Iteration 7
#         > Mean quality of the solutions in this iteration : 88063.7299266127
#
#     • Iteration 8
#         > Mean quality of the solutions in this iteration : 88530.70470864767
#         + New best energy: 64032, with the next distance: 657
#
#     • Iteration 9
#         > Mean quality of the solutions in this iteration : 85268.18777817725
#         + New best energy: 63784, with the next distance: 675
#
#     • Iteration 10
#         > Mean quality of the solutions in this iteration : 87764.9619899647
#
#     • Iteration 11
#         > Mean quality of the solutions in this iteration : 86264.37997515145
#
#     • Iteration 12
#         > Mean quality of the solutions in this iteration : 85649.88748087396
#
#     • Iteration 13
#         > Mean quality of the solutions in this iteration : 85404.9007222618
#
#     • Iteration 14
#         > Mean quality of the solutions in this iteration : 87993.09370337438
#
#     • Iteration 15
#         > Mean quality of the solutions in this iteration : 86188.83445071634
#         + New best energy: 62980, with the next distance: 639
#
#     • Iteration 16
#         > Mean quality of the solutions in this iteration : 87810.9605502485
#
#     • Iteration 17
#         > Mean quality of the solutions in this iteration : 87537.64358953369
#
#     • Iteration 18
#         > Mean quality of the solutions in this iteration : 86609.08440966683
#
#     • Iteration 19
#         > Mean quality of the solutions in this iteration : 86277.84682773444
#
#     • Iteration 20
#         > Mean quality of the solutions in this iteration : 85914.923496719
#
#     • Iteration 21
#         > Mean quality of the solutions in this iteration : 84824.21042213555
#
#     • Iteration 22
#         > Mean quality of the solutions in this iteration : 88347.44773450015
#
#     • Iteration 23
#         > Mean quality of the solutions in this iteration : 87797.81905844313
#
#     • Iteration 24
#         > Mean quality of the solutions in this iteration : 87221.56775092565
#
#     • Iteration 25
#         > Mean quality of the solutions in this iteration : 88958.1437293816
#
#     • Iteration 26
#         > Mean quality of the solutions in this iteration : 86182.39902720273
#
#     • Iteration 27
#         > Mean quality of the solutions in this iteration : 88349.58839743653
#
#     • Iteration 28
#         > Mean quality of the solutions in this iteration : 87099.23708125089
#
#     • Iteration 29
#         > Mean quality of the solutions in this iteration : 87319.53446361229
#
#     • Iteration 30
#         > Mean quality of the solutions in this iteration : 85090.1695305093
#
#     • Iteration 31
#         > Mean quality of the solutions in this iteration : 85537.17385771997
#
#     • Iteration 32
#         > Mean quality of the solutions in this iteration : 88090.87244941582
#
#     • Iteration 33
#         > Mean quality of the solutions in this iteration : 89073.16118465136
#
#     • Iteration 34
#         > Mean quality of the solutions in this iteration : 89970.94504852622
#
#     • Iteration 35
#         > Mean quality of the solutions in this iteration : 88129.53087888127
#
#     • Iteration 36
#         > Mean quality of the solutions in this iteration : 84761.591012679
#
#     • Iteration 37
#         > Mean quality of the solutions in this iteration : 87045.63181023227
#
#     • Iteration 38
#         > Mean quality of the solutions in this iteration : 84626.49399919224
#
#     • Iteration 39
#         > Mean quality of the solutions in this iteration : 86952.17930711745
#
#     • Iteration 40
#         > Mean quality of the solutions in this iteration : 86416.85893466201
#
#     • Iteration 41
#         > Mean quality of the solutions in this iteration : 87964.57545465772
#
#     • Iteration 42
#         > Mean quality of the solutions in this iteration : 87800.19773343651
#
#     • Iteration 43
#         > Mean quality of the solutions in this iteration : 88529.91309320144
#
#     • Iteration 44
#         > Mean quality of the solutions in this iteration : 87526.75819437794
#
#     • Iteration 45
#         > Mean quality of the solutions in this iteration : 87420.67774581749
#         + New best energy: 61517, with the next distance: 645
#
#     • Iteration 46
#         > Mean quality of the solutions in this iteration : 87974.74522882076
#
#     • Iteration 47
#         > Mean quality of the solutions in this iteration : 86414.22244878583
#
#     • Iteration 48
#         > Mean quality of the solutions in this iteration : 87430.66996641984
#
#     • Iteration 49
#         > Mean quality of the solutions in this iteration : 86635.63126316582
#
#     • Iteration 50
#         > Mean quality of the solutions in this iteration : 87521.42323966786
#
#     • Iteration 51
#         > Mean quality of the solutions in this iteration : 88808.06606949092
#
#     • Iteration 52
#         > Mean quality of the solutions in this iteration : 86483.88560390606
#
#     • Iteration 53
#         > Mean quality of the solutions in this iteration : 87796.072100454
#
#     • Iteration 54
#         > Mean quality of the solutions in this iteration : 87963.2842926648
#
#     • Iteration 55
#         > Mean quality of the solutions in this iteration : 87925.25200983117
#
#     • Iteration 56
#         > Mean quality of the solutions in this iteration : 87185.51158917144
#
#     • Iteration 57
#         > Mean quality of the solutions in this iteration : 87372.37293330712
#
#     • Iteration 58
#         > Mean quality of the solutions in this iteration : 86424.07424478358
#         + New best energy: 59415, with the next distance: 635
#
#     • Iteration 59
#         > Mean quality of the solutions in this iteration : 85236.18724904244
#
#     • Iteration 60
#         > Mean quality of the solutions in this iteration : 88351.71657040846
#
#     • Iteration 61
#         > Mean quality of the solutions in this iteration : 84150.3448153771
#
#     • Iteration 62
#         > Mean quality of the solutions in this iteration : 87354.59486846934
#
#     • Iteration 63
#         > Mean quality of the solutions in this iteration : 86031.4668362785
#
#     • Iteration 64
#         > Mean quality of the solutions in this iteration : 85083.51216444053
#
#     • Iteration 65
#         > Mean quality of the solutions in this iteration : 87323.84080866566
#
#     • Iteration 66
#         > Mean quality of the solutions in this iteration : 87141.54681923785
#
#     • Iteration 67
#         > Mean quality of the solutions in this iteration : 86955.27368403197
#
#     • Iteration 68
#         > Mean quality of the solutions in this iteration : 87445.32593894032
#
#     • Iteration 69
#         > Mean quality of the solutions in this iteration : 86818.36811791832
#
#     • Iteration 70
#         > Mean quality of the solutions in this iteration : 88014.74083059802
#
#     • Iteration 71
#         > Mean quality of the solutions in this iteration : 83313.16787856579
#
#     • Iteration 72
#         > Mean quality of the solutions in this iteration : 86226.81772222524
#
#     • Iteration 73
#         > Mean quality of the solutions in this iteration : 88163.37236003284
#
#     • Iteration 74
#         > Mean quality of the solutions in this iteration : 88515.93429217237
#
#     • Iteration 75
#         > Mean quality of the solutions in this iteration : 87769.4828775929
#
#     • Iteration 76
#         > Mean quality of the solutions in this iteration : 87414.31063850595
#
#     • Iteration 77
#         > Mean quality of the solutions in this iteration : 88098.89340172969
#
#     • Iteration 78
#         > Mean quality of the solutions in this iteration : 86843.3134634925
#
#     • Iteration 79
#         > Mean quality of the solutions in this iteration : 86648.5552132553
#
#     • Iteration 80
#         > Mean quality of the solutions in this iteration : 87683.06663141146
#
#     • Iteration 81
#         > Mean quality of the solutions in this iteration : 88397.225085297
#
#     • Iteration 82
#         > Mean quality of the solutions in this iteration : 88346.85817866054
#
#     • Iteration 83
#         > Mean quality of the solutions in this iteration : 88178.8039574752
#
#     • Iteration 84
#         > Mean quality of the solutions in this iteration : 87020.93959498122
#
#     • Iteration 85
#         > Mean quality of the solutions in this iteration : 87739.73988254575
#
#     • Iteration 86
#         > Mean quality of the solutions in this iteration : 86671.76367649954
#
#     • Iteration 87
#         > Mean quality of the solutions in this iteration : 89020.8293731404
#
#     • Iteration 88
#         > Mean quality of the solutions in this iteration : 88199.38750712485
#
#     • Iteration 89
#         > Mean quality of the solutions in this iteration : 86334.43958570129
#         - The Pheromone Matrix has been restarted.
#
#     • Iteration 90
#         > Mean quality of the solutions in this iteration : 88070.8651800943
#
#     • Iteration 91
#         > Mean quality of the solutions in this iteration : 85570.83673536888
#
#     • Iteration 92
#         > Mean quality of the solutions in this iteration : 86747.0063479067
#
#     • Iteration 93
#         > Mean quality of the solutions in this iteration : 88052.4949715524
#
#     • Iteration 94
#         > Mean quality of the solutions in this iteration : 84471.79788572187
#
#     • Iteration 95
#         > Mean quality of the solutions in this iteration : 88308.53132469313
#
#     • Iteration 96
#         > Mean quality of the solutions in this iteration : 86366.23801218391
#
#     • Iteration 97
#         > Mean quality of the solutions in this iteration : 85790.30124295541
#
#     • Iteration 98
#         > Mean quality of the solutions in this iteration : 88938.80930915367
#
#     • Iteration 99
#         > Mean quality of the solutions in this iteration : 86359.9238133235
#
#     • Iteration 100
#         > Mean quality of the solutions in this iteration : 87990.24745756386
#
#     • Global best routes:
#         - Route 0: [0, 44, 15, 17, 37, 45, 33, 39, 10, 30, 34, 9, 50, 0], with final total demand: 156
#         - Route 1: [0, 22, 29, 21, 20, 35, 36, 3, 28, 31, 26, 8, 27, 0], with final total demand: 159
#         - Route 2: [0, 4, 41, 13, 19, 40, 42, 47, 18, 46, 0], with final total demand: 159
#         - Route 3: [0, 32, 1, 48, 6, 23, 7, 43, 24, 14, 25, 0], with final total demand: 156
#         - Route 4: [0, 49, 38, 11, 16, 2, 5, 12, 0], with final total demand: 147
#         - Final total energy: 59415.415017059175
#         - Final total distance: 635.2357839958984
#         - Total time: 3.2440085411071777 seconds.
#
#
# [(60822.48338681596, 676.3358812031227, 3.297027826309204), (61032.66207489619, 667.3115753903277, 3.2425332069396973), (64651.27742902249, 693.1462098685648, 3.2130701541900635), (60895.63622661908, 689.2753155258234, 3.213923692703247), (63580.66838751113, 684.7438847402434, 3.2770822048187256), (64045.17842148429, 671.2607312919852, 3.2344884872436523), (59124.49248071178, 671.4040955263313, 3.2280073165893555), (60428.21546419189, 634.0766961238478, 3.2260096073150635), (60142.98446851791, 644.6272565943655, 3.2200071811676025), (59415.415017059175, 635.2357839958984, 3.2440085411071777)]
# Best Solution: (59124.49248071178, 671.4040955263313, 3.2280073165893555) on run: 7
